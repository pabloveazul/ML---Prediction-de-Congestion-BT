# %%
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot
from pandas import read_csv
from pandas import DataFrame
from pandas import Series
from pandas import concat
from pandas import read_excel
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras import metrics
import numpy as np
import numpy
import keras
dataset = read_excel(r'C:\Users\euripab\Desktop\ML Extraction\Statistics\results2_MeanMaxMin_SupervisedData\supervised_all_14_1.xlsx')
dataset = dataset.sample(frac=1, replace=False)
#dataset = dataset.reset_index(drop=True)
dataset
# Out:
#       CQImoyen mean(t-14)  CQImoyen min(t-14)  CQImoyen max(t-14)  \
# 2381            13.395294               12.88               13.99
# 3841             8.742941                7.96                9.71
# 2963             0.000000                0.00                0.00
# 423             10.392941                9.38               11.98
# 3042             8.991176                8.38                9.85
# 1492            13.748235                0.00               14.89
# 3114             9.357647                8.58               10.10
# 552              7.682353                7.07                8.52
# 1495             0.000000                0.00                0.00
# 2111            12.462353               11.85               13.74
# 3869             9.242353                8.42               10.24
# 3057             9.153529                8.34               10.74
# 1368            14.484706               14.34               14.60
# 3419             9.305294                8.81                9.96
# 3402             9.084706                8.36               10.13
# 1586            11.551176               10.76               12.72
# 1081            14.041765               13.79               14.18
# 1173            14.242353               12.84               14.74
# 2965             0.000000                0.00                0.00
# 277             10.158235                9.39               11.10
# 2202            12.695882               12.46               13.00
# 4098            12.647059               11.84               13.76
# 2617            14.077647               13.78               14.27
# 1732            12.807647               12.32               13.61
# 3235            11.052353               10.39               12.03
# 610             11.587647               10.09               12.88
# 630             11.076471               10.32               11.93
# 2067             8.194706                0.00                9.55
# 2221            10.648235               10.17               11.38
# 1949            11.745294               11.29               12.47
# ...                   ...                 ...                 ...
# 3346            10.752353               10.03               11.82
# 2796            14.098824               13.87               14.51
# 2987            14.529412               13.92               14.96
# 2433            10.777059                9.87               11.66
# 3053             9.651765                8.67               11.03
# 3397            10.209412                9.03               11.82
# 3898            10.767059                8.31               12.48
# 2414            11.388824               10.85               11.97
# 3505            10.144706                9.19               10.67
# 2730            14.012353               12.03               14.86
# 388             12.316471               11.98               13.10
# 3848             8.716471                7.83                9.85
# 3201             9.652353                9.13               10.91
# 851             10.641176                9.56               12.18
# 2630            14.338235               14.22               14.53
# 1168            13.016471               12.49               13.45
# 2190            12.520588               12.05               13.34
# 2064             9.273529                8.73               10.16
# 1262            14.348235               14.20               14.46
# 1004            11.412941               10.82               12.02
# 1880            14.377059               14.22               14.56
# 2539            12.728235               12.05               13.29
# 883             11.064706               10.57               11.74
# 3915            11.342353                9.52               12.28
# 2644            14.334118               14.22               14.44
# 1284            14.484118               14.31               14.59
# 1770            12.530588               12.23               12.80
# 2822            14.494706               14.02               14.70
# 586             10.790000               10.16               11.27
# 2640            14.380588               14.29               14.52
#
#       TraficDataDL mean(t-14)  TraficDataDL min(t-14)  TraficDataDL max(t-14)  \
# 2381              1254.802941                   38.75                 3822.32
# 3841               967.831765                  126.70                 1588.28
# 2963                 0.000000                    0.00                    0.00
# 423                793.813529                   95.55                 1780.22
# 3042              1611.307647                  241.37                 4848.90
# 1492               363.571765                    0.00                  988.87
# 3114               278.685294                   65.18                  638.53
# 552               1258.779412                  136.86                 2908.39
# 2822                           133.764706                                  51
# 586                            514.352941                                 325
# 2640                            48.000000                                   4
#
#       Nbrtentatives_QCi5__TEAVoix max(t)
# 2381                                 428
# 3841                                1475
# 2963                                   0
# 423                                 1221
# 3042                                1667
# 1492                                1704
# 3114                                 229
# 552                                  258
# 1495                                   0
# 2111                                 370
# 3869                                 117
# 3057                                3797
# 1368                                 288
# 3419                                1370
# 3402                                1265
# 1586                                2041
# 1081                                2015
# 1173                                 124
# 2965                                   0
# 277                                  920
# 2202                                 530
# 4098                                 126
# 2617                                1206
# 1732                                7253
# 3235                                 261
# 610                                  178
# 630                                  969
# 2067                                3473
# 2221                                3757
# 1949                                 228
# ...                                  ...
# 3346                                2492
# 2796                                 866
# 2987                                1142
# 2433                                 263
# 3053                                 597
# 3397                                 613
# 3898                                  33
# 2414                                1032
# 3505                                 906
# 2730                                 187
# 388                                 1528
# 3848                                1609
# 3201                                3495
# 851                                  690
# 2630                                 234
# 1168                                2288
# 2190                                 486
# 2064                                1356
# 1262                                 366
# 1004                                 745
# 1880                                 825
# 2539                                 487
# 883                                  918
# 3915                                  72
# 2644                                 214
# 1284                                 318
# 1770                                2842
# 2822                                 256
# 586                                  781
# 2640                                 110
#
# [4140 rows x 315 columns]

# %%
values = dataset.values


n_days_pred = 1 
n_days = 14
n_features = 7*3
n_obs = n_days*n_features
n_train_samples = 1000
values = values.astype('float32')
#Scale Data
scaler = MinMaxScaler()
values = scaler.fit_transform(values)

dictionary = dict(zip(dataset.columns, range(0,len(dataset.columns))))

train = values[:n_train_samples, :]
test = values[n_train_samples:, :]
# split into input and outputs
n_obs = n_days * n_features
train_X, train_y = train[:, [(i-1)*7*n_features+j for j in range(0,n_features) for i in range(1,3)]], train[:,dictionary['CQImoyen max(t)']]
test_X, test_y = test[:, [(i-1)*7*n_features+j for j in range(0,n_features) for i in range(1,3)]], test[:,dictionary['CQImoyen max(t)']]


#Split Values into Classification columns
#train_y = keras.utils.to_categorical(train_y,num_classes=num_classes)
#test_y = keras.utils.to_categorical(test_y,num_classes=num_classes)
# reshape input to be 3D [samples, timesteps, features]
#train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
#test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
#print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
dim = len([(i-1)*7*n_features+j for j in range(0,n_features) for i in range(1,3)])

# design network
model = Sequential()
model.add(Dense(dim*10, activation='relu', input_dim =dim))
model.add(Dense(dim*2, activation='sigmoid'))
model.add(Dense(1,activation = 'relu'))
model.compile(loss='mse', optimizer='rmsprop',metrics=[metrics.mse])
# fit network
history = model.fit(train_X, train_y, epochs=50, batch_size=72, validation_data=(test_X, test_y),verbose = 2, shuffle=False)
# plot history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()
# make a prediction
yhat = model.predict(test_X)

rmse = sqrt(mean_squared_error(test_y, yhat))
print('Test RMSE: %.3f' % rmse)
# Out:
# Train on 1000 samples, validate on 3140 samples
# Epoch 1/50
#  - 0s - loss: 0.0366 - mean_squared_error: 0.0366 - val_loss: 0.0219 - val_mean_squared_error: 0.0219
# Epoch 2/50
#  - 0s - loss: 0.0225 - mean_squared_error: 0.0225 - val_loss: 0.0171 - val_mean_squared_error: 0.0171
# Epoch 3/50
#  - 0s - loss: 0.0178 - mean_squared_error: 0.0178 - val_loss: 0.0149 - val_mean_squared_error: 0.0149
# Epoch 4/50
#  - 0s - loss: 0.0148 - mean_squared_error: 0.0148 - val_loss: 0.0144 - val_mean_squared_error: 0.0144
# Epoch 5/50
#  - 0s - loss: 0.0129 - mean_squared_error: 0.0129 - val_loss: 0.0146 - val_mean_squared_error: 0.0146
# Epoch 6/50
#  - 0s - loss: 0.0119 - mean_squared_error: 0.0119 - val_loss: 0.0143 - val_mean_squared_error: 0.0143
# Epoch 7/50
#  - 0s - loss: 0.0113 - mean_squared_error: 0.0113 - val_loss: 0.0144 - val_mean_squared_error: 0.0144
# Epoch 8/50
#  - 0s - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0142 - val_mean_squared_error: 0.0142
# Epoch 9/50
#  - 0s - loss: 0.0108 - mean_squared_error: 0.0108 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
# Epoch 10/50
#  - 0s - loss: 0.0105 - mean_squared_error: 0.0105 - val_loss: 0.0138 - val_mean_squared_error: 0.0138
# Epoch 11/50
#  - 0s - loss: 0.0103 - mean_squared_error: 0.0103 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
# Epoch 12/50
#  - 0s - loss: 0.0103 - mean_squared_error: 0.0103 - val_loss: 0.0138 - val_mean_squared_error: 0.0138
# Epoch 13/50
#  - 0s - loss: 0.0101 - mean_squared_error: 0.0101 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
# Epoch 14/50
#  - 0s - loss: 0.0101 - mean_squared_error: 0.0101 - val_loss: 0.0132 - val_mean_squared_error: 0.0132
# Epoch 15/50
#  - 0s - loss: 0.0099 - mean_squared_error: 0.0099 - val_loss: 0.0133 - val_mean_squared_error: 0.0133
# Epoch 16/50
#  - 0s - loss: 0.0098 - mean_squared_error: 0.0098 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
# Epoch 17/50
#  - 0s - loss: 0.0098 - mean_squared_error: 0.0098 - val_loss: 0.0131 - val_mean_squared_error: 0.0131
# Epoch 18/50
#  - 0s - loss: 0.0097 - mean_squared_error: 0.0097 - val_loss: 0.0133 - val_mean_squared_error: 0.0133
# Epoch 19/50
#  - 0s - loss: 0.0096 - mean_squared_error: 0.0096 - val_loss: 0.0133 - val_mean_squared_error: 0.0133
# Epoch 20/50
#  - 0s - loss: 0.0095 - mean_squared_error: 0.0095 - val_loss: 0.0136 - val_mean_squared_error: 0.0136
# Epoch 21/50
#  - 0s - loss: 0.0096 - mean_squared_error: 0.0096 - val_loss: 0.0125 - val_mean_squared_error: 0.0125
# Epoch 22/50
#  - 0s - loss: 0.0094 - mean_squared_error: 0.0094 - val_loss: 0.0126 - val_mean_squared_error: 0.0126
# Epoch 23/50
#  - 0s - loss: 0.0094 - mean_squared_error: 0.0094 - val_loss: 0.0127 - val_mean_squared_error: 0.0127
# Epoch 24/50
#  - 0s - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0131 - val_mean_squared_error: 0.0131
# Epoch 25/50
#  - 0s - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0126 - val_mean_squared_error: 0.0126
# Epoch 26/50
#  - 0s - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 27/50
#  - 0s - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0120 - val_mean_squared_error: 0.0120
# Epoch 28/50
#  - 0s - loss: 0.0090 - mean_squared_error: 0.0090 - val_loss: 0.0132 - val_mean_squared_error: 0.0132
# Epoch 29/50
#  - 0s - loss: 0.0090 - mean_squared_error: 0.0090 - val_loss: 0.0126 - val_mean_squared_error: 0.0126
# Epoch 30/50
#  - 0s - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0114 - val_mean_squared_error: 0.0114
# Epoch 31/50
#  - 0s - loss: 0.0090 - mean_squared_error: 0.0090 - val_loss: 0.0112 - val_mean_squared_error: 0.0112
# Epoch 32/50
#  - 0s - loss: 0.0089 - mean_squared_error: 0.0089 - val_loss: 0.0114 - val_mean_squared_error: 0.0114
# Epoch 33/50
#  - 0s - loss: 0.0089 - mean_squared_error: 0.0089 - val_loss: 0.0112 - val_mean_squared_error: 0.0112
# Epoch 34/50
#  - 0s - loss: 0.0090 - mean_squared_error: 0.0090 - val_loss: 0.0109 - val_mean_squared_error: 0.0109
# Epoch 35/50
#  - 0s - loss: 0.0089 - mean_squared_error: 0.0089 - val_loss: 0.0113 - val_mean_squared_error: 0.0113
# Epoch 36/50
#  - 0s - loss: 0.0087 - mean_squared_error: 0.0087 - val_loss: 0.0121 - val_mean_squared_error: 0.0121
# Epoch 37/50
#  - 0s - loss: 0.0087 - mean_squared_error: 0.0087 - val_loss: 0.0114 - val_mean_squared_error: 0.0114
# Epoch 38/50
#  - 0s - loss: 0.0089 - mean_squared_error: 0.0089 - val_loss: 0.0108 - val_mean_squared_error: 0.0108
# Epoch 39/50
#  - 0s - loss: 0.0094 - mean_squared_error: 0.0094 - val_loss: 0.0139 - val_mean_squared_error: 0.0139
# Epoch 40/50
#  - 0s - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0133 - val_mean_squared_error: 0.0133
# Epoch 41/50
#  - 0s - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0112 - val_mean_squared_error: 0.0112
# Epoch 42/50
#  - 0s - loss: 0.0089 - mean_squared_error: 0.0089 - val_loss: 0.0127 - val_mean_squared_error: 0.0127
# Epoch 43/50
#  - 0s - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0154 - val_mean_squared_error: 0.0154
# Epoch 44/50
#  - 0s - loss: 0.0084 - mean_squared_error: 0.0084 - val_loss: 0.0112 - val_mean_squared_error: 0.0112
# Epoch 45/50
#  - 0s - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0110 - val_mean_squared_error: 0.0110
# Epoch 46/50
#  - 0s - loss: 0.0089 - mean_squared_error: 0.0089 - val_loss: 0.0109 - val_mean_squared_error: 0.0109
# Epoch 47/50
#  - 0s - loss: 0.0087 - mean_squared_error: 0.0087 - val_loss: 0.0108 - val_mean_squared_error: 0.0108
# Epoch 48/50
#  - 0s - loss: 0.0086 - mean_squared_error: 0.0086 - val_loss: 0.0109 - val_mean_squared_error: 0.0109
# Epoch 49/50
#  - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - val_loss: 0.0109 - val_mean_squared_error: 0.0109
# Epoch 50/50
#  - 0s - loss: 0.0086 - mean_squared_error: 0.0086 - val_loss: 0.0109 - val_mean_squared_error: 0.0109
# Test RMSE: 0.105

# %%
y_pred_train = model.predict(train_X)

# %%
DataFrame(y_pred_train).plot(figsize = (10,10))
DataFrame(y_pred_train).hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000016DADC88>]],
#       dtype=object)

# %%
DataFrame(train_y).plot(figsize = (10,10))
DataFrame(train_y).hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000000108A20F0>]],
#       dtype=object)

# %%
res = DataFrame()
n = np.random.choice(len(train_y), 100)
res['Pred Train'] = DataFrame(y_pred_train[n])[0]
res['True Train'] = DataFrame(train_y[n])[0]
res.plot(figsize = (10,10))

# %%
y_pred_test = model.predict(test_X)
DataFrame(y_pred_test).plot()
DataFrame(y_pred_test).hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000015833D68>]],
#       dtype=object)

# %%
DataFrame(test_y).plot()
DataFrame(test_y).hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000000180AAEB8>]],
#       dtype=object)

# %%
res = DataFrame()
n = np.random.choice(len(test_y), 100)
res['Pred Test'] = DataFrame(y_pred_test[n])[0]
res['True Test'] = DataFrame(test_y[n])[0]
res.plot(figsize = (10,10))

# %%
mask1 = [DataFrame(yhat)[0]>0.5]
numpy.sum(mask1)
# Out:
# 3077

# %%
mask2 = [DataFrame(test_y)[0]>0.5]
numpy.sum(mask2)
# Out:
# 3074

# %%
a = [mask1[i] == mask2[i] for i in range(0,len(mask1))]
numpy.sum(a)/len(test)
# Out:
# 0.021019108280254776

# %%
cellKpi= pd.read_excel(r'C:\Users\euripab\Desktop\ML Extraction\Statistics\results1_MeanMaxMin_PerDay\MeanMaxMin_PerDay_all_D10664B.xlsx')
cellKpi.plot(y =cellKpi.columns, kind='line',figsize = (15,10))

# %%
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	n_vars = 1 if type(data) is list else data.shape[1]
	df = pd.DataFrame(data)
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
		names += [(name+'(t-%d)' % (i)) for name in data.columns]
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df.shift(-i))
		if i == 0:
			names += [name+'(t)' for name in data.columns]
		else:
			names += [(name+'(t+%d)' % (i)) for name in data.columns]
	# put it all together
	agg = pd.concat(cols, axis=1)
	agg.columns = names
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg

# %%
example_values = series_to_supervised(cellKpi, n_in=1, n_out=7, dropnan=True).values
example_values = scaler.transform(example_values)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-443d331297db> in <module>()
#       1 example_values = series_to_supervised(cellKpi, n_in=1, n_out=7, dropnan=True).values
# ----> 2 example_values = scaler.transform(example_values)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\preprocessing\data.py in transform(self, X)
#     367         X = check_array(X, copy=self.copy, dtype=FLOAT_DTYPES)
#     368
# --> 369         X *= self.scale_
#     370         X += self.min_
#     371         return X
#
# ValueError: operands could not be broadcast together with shapes (25,168) (315,) (25,168)

# %%
example_values_X = example_values[:, range(0,n_obs)]
example_values_y = example_values[:, n_obs+(n_days_pred-1)*n_features+1]

# %%
yhat = model.predict(example_values_X)

# %%
ex = DataFrame()
ex['Pred'] = DataFrame(yhat)[0]
ex['True'] = DataFrame(example_values_y)[0]
ex.plot()

# %%
dictionary
# Out:
# {'CQImoyen mean(t-14)': 0,
#  'CQImoyen min(t-14)': 1,
#  'CQImoyen max(t-14)': 2,
#  'TraficDataDL mean(t-14)': 3,
#  'TraficDataDL min(t-14)': 4,
#  'TraficDataDL max(t-14)': 5,
#  'TraficDataUL mean(t-14)': 6,
#  'TraficDataUL min(t-14)': 7,
#  'TraficDataUL max(t-14)': 8,
#  'VoIPqualitymeasinsuffstat mean(t-14)': 9,
#  'VoIPqualitymeasinsuffstat min(t-14)': 10,
#  'VoIPqualitymeasinsuffstat max(t-14)': 11,
#  'CROZON_NombredeConnexionsPS mean(t-14)': 12,
#  'CROZON_NombredeConnexionsPS min(t-14)': 13,
#  'CROZON_NombredeConnexionsPS max(t-14)': 14,
#  'nbUEVoIPqualityOK mean(t-14)': 15,
#  'nbUEVoIPqualityOK min(t-14)': 16,
#  'nbUEVoIPqualityOK max(t-14)': 17,
#  'Nbrtentatives_QCi5__TEAVoix mean(t-14)': 18,
#  'Nbrtentatives_QCi5__TEAVoix min(t-14)': 19,
#  'Nbrtentatives_QCi5__TEAVoix max(t-14)': 20,
#  'CQImoyen mean(t-13)': 21,
#  'CQImoyen min(t-13)': 22,
#  'CQImoyen max(t-13)': 23,
#  'TraficDataDL mean(t-13)': 24,
#  'TraficDataDL min(t-13)': 25,
#  'TraficDataDL max(t-13)': 26,
#  'TraficDataUL mean(t-13)': 27,
#  'TraficDataUL min(t-13)': 28,
#  'TraficDataUL max(t-13)': 29,
#  'VoIPqualitymeasinsuffstat mean(t-13)': 30,
#  'VoIPqualitymeasinsuffstat min(t-13)': 31,
#  'VoIPqualitymeasinsuffstat max(t-13)': 32,
#  'CROZON_NombredeConnexionsPS mean(t-13)': 33,
#  'CROZON_NombredeConnexionsPS min(t-13)': 34,
#  'CROZON_NombredeConnexionsPS max(t-13)': 35,
#  'nbUEVoIPqualityOK mean(t-13)': 36,
#  'nbUEVoIPqualityOK min(t-13)': 37,
#  'nbUEVoIPqualityOK max(t-13)': 38,
#  'Nbrtentatives_QCi5__TEAVoix mean(t-13)': 39,
#  'Nbrtentatives_QCi5__TEAVoix min(t-13)': 40,
#  'Nbrtentatives_QCi5__TEAVoix max(t-13)': 41,
#  'CQImoyen mean(t-12)': 42,
#  'CQImoyen min(t-12)': 43,
#  'CQImoyen max(t-12)': 44,
#  'TraficDataDL mean(t-12)': 45,
#  'TraficDataDL min(t-12)': 46,
#  'TraficDataDL max(t-12)': 47,
#  'TraficDataUL mean(t-12)': 48,
#  'TraficDataUL min(t-12)': 49,
#  'TraficDataUL max(t-12)': 50,
#  'VoIPqualitymeasinsuffstat mean(t-12)': 51,
#  'VoIPqualitymeasinsuffstat min(t-12)': 52,
#  'VoIPqualitymeasinsuffstat max(t-12)': 53,
#  'CROZON_NombredeConnexionsPS mean(t-12)': 54,
#  'CROZON_NombredeConnexionsPS min(t-12)': 55,
#  'CROZON_NombredeConnexionsPS max(t-12)': 56,
#  'nbUEVoIPqualityOK mean(t-12)': 57,
#  'nbUEVoIPqualityOK min(t-12)': 58,
#  'nbUEVoIPqualityOK max(t-12)': 59,
#  'Nbrtentatives_QCi5__TEAVoix mean(t-12)': 60,
#  'Nbrtentatives_QCi5__TEAVoix min(t-12)': 61,
#  'Nbrtentatives_QCi5__TEAVoix max(t-12)': 62,
#  'CQImoyen mean(t-11)': 63,
#  'CQImoyen min(t-11)': 64,
#  'CQImoyen max(t-11)': 65,
#  'TraficDataDL mean(t-11)': 66,
#  'TraficDataDL min(t-11)': 67,
#  'TraficDataDL max(t-11)': 68,
#  'TraficDataUL mean(t-11)': 69,
#  'TraficDataUL min(t-11)': 70,
#  'TraficDataUL max(t-11)': 71,
#  'VoIPqualitymeasinsuffstat mean(t-11)': 72,
#  'VoIPqualitymeasinsuffstat min(t-11)': 73,
#  'VoIPqualitymeasinsuffstat max(t-11)': 74,
#  'CROZON_NombredeConnexionsPS mean(t-11)': 75,
#  'CROZON_NombredeConnexionsPS min(t-11)': 76,
#  'CROZON_NombredeConnexionsPS max(t-11)': 77,
#  'nbUEVoIPqualityOK mean(t-11)': 78,
#  'nbUEVoIPqualityOK min(t-11)': 79,
#  'nbUEVoIPqualityOK max(t-11)': 80,
#  'Nbrtentatives_QCi5__TEAVoix mean(t-11)': 81,
#  'Nbrtentatives_QCi5__TEAVoix min(t-11)': 82,
#  'Nbrtentatives_QCi5__TEAVoix max(t-11)': 83,
#  'CQImoyen mean(t-10)': 84,
#  'CQImoyen min(t-10)': 85,
#  'CQImoyen max(t-10)': 86,
#  'TraficDataDL mean(t-10)': 87,
#  'TraficDataDL min(t-10)': 88,
#  'TraficDataDL max(t-10)': 89,
#  'TraficDataUL mean(t-10)': 90,
#  'TraficDataUL min(t-10)': 91,
#  'TraficDataUL max(t-10)': 92,
#  'VoIPqualitymeasinsuffstat mean(t-10)': 93,
#  'VoIPqualitymeasinsuffstat min(t-10)': 94,
#  'VoIPqualitymeasinsuffstat max(t-10)': 95,
#  'CROZON_NombredeConnexionsPS mean(t-10)': 96,
#  'CROZON_NombredeConnexionsPS min(t-10)': 97,
#  'CROZON_NombredeConnexionsPS max(t-10)': 98,
#  'nbUEVoIPqualityOK mean(t-10)': 99,
#  'nbUEVoIPqualityOK min(t-10)': 100,
#  'nbUEVoIPqualityOK max(t-10)': 101,
#  'Nbrtentatives_QCi5__TEAVoix mean(t-10)': 102,
#  'Nbrtentatives_QCi5__TEAVoix min(t-10)': 103,
#  'Nbrtentatives_QCi5__TEAVoix max(t-10)': 104,
#  'CQImoyen mean(t-9)': 105,
#  'CQImoyen min(t-9)': 106,
#  'CQImoyen max(t-9)': 107,
#  'TraficDataDL mean(t-9)': 108,
#  'TraficDataDL min(t-9)': 109,
#  'TraficDataDL max(t-9)': 110,
#  'TraficDataUL mean(t-9)': 111,
#  'TraficDataUL min(t-9)': 112,
#  'TraficDataUL max(t-9)': 113,
#  'VoIPqualitymeasinsuffstat mean(t-9)': 114,
#  'VoIPqualitymeasinsuffstat min(t-9)': 115,
#  'VoIPqualitymeasinsuffstat max(t-9)': 116,
#  'CROZON_NombredeConnexionsPS mean(t-9)': 117,
#  'CROZON_NombredeConnexionsPS min(t-9)': 118,
#  'CROZON_NombredeConnexionsPS max(t-9)': 119,
#  'nbUEVoIPqualityOK mean(t-9)': 120,
#  'nbUEVoIPqualityOK min(t-9)': 121,
#  'nbUEVoIPqualityOK max(t-9)': 122,
#  'Nbrtentatives_QCi5__TEAVoix mean(t-9)': 123,
#  'Nbrtentatives_QCi5__TEAVoix min(t-9)': 124,
#  'Nbrtentatives_QCi5__TEAVoix max(t-9)': 125,
#  'CQImoyen mean(t-8)': 126,
#  'CQImoyen min(t-8)': 127,
#  'CQImoyen max(t-8)': 128,
#  'TraficDataDL mean(t-8)': 129,
#  'TraficDataDL min(t-8)': 130,
#  'TraficDataDL max(t-8)': 131,
#  'TraficDataUL mean(t-8)': 132,
#  'TraficDataUL min(t-8)': 133,
#  'TraficDataUL max(t-8)': 134,
#  'VoIPqualitymeasinsuffstat mean(t-8)': 135,
#  'VoIPqualitymeasinsuffstat min(t-8)': 136,
#  'VoIPqualitymeasinsuffstat max(t-8)': 137,
#  'CROZON_NombredeConnexionsPS mean(t-8)': 138,
#  'CROZON_NombredeConnexionsPS min(t-8)': 139,
#  'CROZON_NombredeConnexionsPS max(t-8)': 140,
#  'nbUEVoIPqualityOK mean(t-8)': 141,
#  'nbUEVoIPqualityOK min(t-8)': 142,
#  'nbUEVoIPqualityOK max(t-8)': 143,
#  'Nbrtentatives_QCi5__TEAVoix mean(t-8)': 144,
#  'Nbrtentatives_QCi5__TEAVoix min(t-8)': 145,
#  'Nbrtentatives_QCi5__TEAVoix max(t-8)': 146,
#  'CQImoyen mean(t-7)': 147,
#  'CQImoyen min(t-7)': 148,
#  'CQImoyen max(t-7)': 149,
#  'TraficDataDL mean(t-7)': 150,
#  'TraficDataDL min(t-7)': 151,
#  'TraficDataDL max(t-7)': 152,
#  'TraficDataUL mean(t-7)': 153,
#  'TraficDataUL min(t-7)': 154,
#  'TraficDataUL max(t-7)': 155,
#  'VoIPqualitymeasinsuffstat mean(t-7)': 156,
#  'VoIPqualitymeasinsuffstat min(t-7)': 157,
#  'VoIPqualitymeasinsuffstat max(t-7)': 158,
#  'CROZON_NombredeConnexionsPS mean(t-7)': 159,
#  'CROZON_NombredeConnexionsPS min(t-7)': 160,
#  'CROZON_NombredeConnexionsPS max(t-7)': 161,
#  'nbUEVoIPqualityOK mean(t-7)': 162,
#  'nbUEVoIPqualityOK min(t-7)': 163,
#  'nbUEVoIPqualityOK max(t-7)': 164,
#  'Nbrtentatives_QCi5__TEAVoix mean(t-7)': 165,
#  'Nbrtentatives_QCi5__TEAVoix min(t-7)': 166,
#  'Nbrtentatives_QCi5__TEAVoix max(t-7)': 167,
#  'CQImoyen mean(t-6)': 168,
#  'CQImoyen min(t-6)': 169,
#  'CQImoyen max(t-6)': 170,
#  'TraficDataDL mean(t-6)': 171,
#  'TraficDataDL min(t-6)': 172,
#  'TraficDataDL max(t-6)': 173,
#  'TraficDataUL mean(t-6)': 174,
#  'TraficDataUL min(t-6)': 175,
#  'TraficDataUL max(t-6)': 176,
#  'VoIPqualitymeasinsuffstat mean(t-6)': 177,
#  'VoIPqualitymeasinsuffstat min(t-6)': 178,
#  'VoIPqualitymeasinsuffstat max(t-6)': 179,
#  'CROZON_NombredeConnexionsPS mean(t-6)': 180,
#  'CROZON_NombredeConnexionsPS min(t-6)': 181,
#  'CROZON_NombredeConnexionsPS max(t-6)': 182,
#  'nbUEVoIPqualityOK mean(t-6)': 183,
#  'nbUEVoIPqualityOK min(t-6)': 184,
#  'nbUEVoIPqualityOK max(t-6)': 185,
#  'Nbrtentatives_QCi5__TEAVoix mean(t-6)': 186,
#  'Nbrtentatives_QCi5__TEAVoix min(t-6)': 187,
#  'Nbrtentatives_QCi5__TEAVoix max(t-6)': 188,
#  'CQImoyen mean(t-5)': 189,
#  'CQImoyen min(t-5)': 190,
#  'CQImoyen max(t-5)': 191,
#  'TraficDataDL mean(t-5)': 192,
#  'TraficDataDL min(t-5)': 193,
#  'TraficDataDL max(t-5)': 194,
#  'TraficDataUL mean(t-5)': 195,
#  'TraficDataUL min(t-5)': 196,
#  'TraficDataUL max(t-5)': 197,
#  'VoIPqualitymeasinsuffstat mean(t-5)': 198,
#  'VoIPqualitymeasinsuffstat min(t-5)': 199,
#  'VoIPqualitymeasinsuffstat max(t-5)': 200,
#  'CROZON_NombredeConnexionsPS mean(t-5)': 201,
#  'CROZON_NombredeConnexionsPS min(t-5)': 202,
#  'CROZON_NombredeConnexionsPS max(t-5)': 203,
#  'nbUEVoIPqualityOK mean(t-5)': 204,
#  'nbUEVoIPqualityOK min(t-5)': 205,
#  'nbUEVoIPqualityOK max(t-5)': 206,
#  'Nbrtentatives_QCi5__TEAVoix mean(t-5)': 207,
#  'Nbrtentatives_QCi5__TEAVoix min(t-5)': 208,
#  'Nbrtentatives_QCi5__TEAVoix max(t-5)': 209,
#  'CQImoyen mean(t-4)': 210,
#  'CQImoyen min(t-4)': 211,
#  'CQImoyen max(t-4)': 212,
#  'TraficDataDL mean(t-4)': 213,
#  'TraficDataDL min(t-4)': 214,
#  'TraficDataDL max(t-4)': 215,
#  'TraficDataUL mean(t-4)': 216,
#  'TraficDataUL min(t-4)': 217,
#  'TraficDataUL max(t-4)': 218,
#  'VoIPqualitymeasinsuffstat mean(t-4)': 219,
#  'VoIPqualitymeasinsuffstat min(t-4)': 220,
#  'VoIPqualitymeasinsuffstat max(t-4)': 221,
#  'CROZON_NombredeConnexionsPS mean(t-4)': 222,
#  'CROZON_NombredeConnexionsPS min(t-4)': 223,
#  'CROZON_NombredeConnexionsPS max(t-4)': 224,
#  'nbUEVoIPqualityOK mean(t-4)': 225,
#  'nbUEVoIPqualityOK min(t-4)': 226,
#  'nbUEVoIPqualityOK max(t-4)': 227,
#  'Nbrtentatives_QCi5__TEAVoix mean(t-4)': 228,
#  'Nbrtentatives_QCi5__TEAVoix min(t-4)': 229,
#  'Nbrtentatives_QCi5__TEAVoix max(t-4)': 230,
#  'CQImoyen mean(t-3)': 231,
#  'CQImoyen min(t-3)': 232,
#  'CQImoyen max(t-3)': 233,
#  'TraficDataDL mean(t-3)': 234,
#  'TraficDataDL min(t-3)': 235,
#  'TraficDataDL max(t-3)': 236,
#  'TraficDataUL mean(t-3)': 237,
#  'TraficDataUL min(t-3)': 238,
#  'TraficDataUL max(t-3)': 239,
#  'VoIPqualitymeasinsuffstat mean(t-3)': 240,
#  'VoIPqualitymeasinsuffstat min(t-3)': 241,
#  'VoIPqualitymeasinsuffstat max(t-3)': 242,
#  'CROZON_NombredeConnexionsPS mean(t-3)': 243,
#  'CROZON_NombredeConnexionsPS min(t-3)': 244,
#  'CROZON_NombredeConnexionsPS max(t-3)': 245,
#  'nbUEVoIPqualityOK mean(t-3)': 246,
#  'nbUEVoIPqualityOK min(t-3)': 247,
#  'nbUEVoIPqualityOK max(t-3)': 248,
#  'Nbrtentatives_QCi5__TEAVoix mean(t-3)': 249,
#  'Nbrtentatives_QCi5__TEAVoix min(t-3)': 250,
#  'Nbrtentatives_QCi5__TEAVoix max(t-3)': 251,
#  'CQImoyen mean(t-2)': 252,
#  'CQImoyen min(t-2)': 253,
#  'CQImoyen max(t-2)': 254,
#  'TraficDataDL mean(t-2)': 255,
#  'TraficDataDL min(t-2)': 256,
#  'TraficDataDL max(t-2)': 257,
#  'TraficDataUL mean(t-2)': 258,
#  'TraficDataUL min(t-2)': 259,
#  'TraficDataUL max(t-2)': 260,
#  'VoIPqualitymeasinsuffstat mean(t-2)': 261,
#  'VoIPqualitymeasinsuffstat min(t-2)': 262,
#  'VoIPqualitymeasinsuffstat max(t-2)': 263,
#  'CROZON_NombredeConnexionsPS mean(t-2)': 264,
#  'CROZON_NombredeConnexionsPS min(t-2)': 265,
#  'CROZON_NombredeConnexionsPS max(t-2)': 266,
#  'nbUEVoIPqualityOK mean(t-2)': 267,
#  'nbUEVoIPqualityOK min(t-2)': 268,
#  'nbUEVoIPqualityOK max(t-2)': 269,
#  'Nbrtentatives_QCi5__TEAVoix mean(t-2)': 270,
#  'Nbrtentatives_QCi5__TEAVoix min(t-2)': 271,
#  'Nbrtentatives_QCi5__TEAVoix max(t-2)': 272,
#  'CQImoyen mean(t-1)': 273,
#  'CQImoyen min(t-1)': 274,
#  'CQImoyen max(t-1)': 275,
#  'TraficDataDL mean(t-1)': 276,
#  'TraficDataDL min(t-1)': 277,
#  'TraficDataDL max(t-1)': 278,
#  'TraficDataUL mean(t-1)': 279,
#  'TraficDataUL min(t-1)': 280,
#  'TraficDataUL max(t-1)': 281,
#  'VoIPqualitymeasinsuffstat mean(t-1)': 282,
#  'VoIPqualitymeasinsuffstat min(t-1)': 283,
#  'VoIPqualitymeasinsuffstat max(t-1)': 284,
#  'CROZON_NombredeConnexionsPS mean(t-1)': 285,
#  'CROZON_NombredeConnexionsPS min(t-1)': 286,
#  'CROZON_NombredeConnexionsPS max(t-1)': 287,
#  'nbUEVoIPqualityOK mean(t-1)': 288,
#  'nbUEVoIPqualityOK min(t-1)': 289,
#  'nbUEVoIPqualityOK max(t-1)': 290,
#  'Nbrtentatives_QCi5__TEAVoix mean(t-1)': 291,
#  'Nbrtentatives_QCi5__TEAVoix min(t-1)': 292,
#  'Nbrtentatives_QCi5__TEAVoix max(t-1)': 293,
#  'CQImoyen mean(t)': 294,
#  'CQImoyen min(t)': 295,
#  'CQImoyen max(t)': 296,
#  'TraficDataDL mean(t)': 297,
#  'TraficDataDL min(t)': 298,
#  'TraficDataDL max(t)': 299,
#  'TraficDataUL mean(t)': 300,
#  'TraficDataUL min(t)': 301,
#  'TraficDataUL max(t)': 302,
#  'VoIPqualitymeasinsuffstat mean(t)': 303,
#  'VoIPqualitymeasinsuffstat min(t)': 304,
#  'VoIPqualitymeasinsuffstat max(t)': 305,
#  'CROZON_NombredeConnexionsPS mean(t)': 306,
#  'CROZON_NombredeConnexionsPS min(t)': 307,
#  'CROZON_NombredeConnexionsPS max(t)': 308,
#  'nbUEVoIPqualityOK mean(t)': 309,
#  'nbUEVoIPqualityOK min(t)': 310,
#  'nbUEVoIPqualityOK max(t)': 311,
#  'Nbrtentatives_QCi5__TEAVoix mean(t)': 312,
#  'Nbrtentatives_QCi5__TEAVoix min(t)': 313,
#  'Nbrtentatives_QCi5__TEAVoix max(t)': 314}

# %%
# Out:
# 275
