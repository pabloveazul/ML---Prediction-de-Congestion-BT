# %%
# coding: utf-8

import matplotlib.pyplot as plt
import pandas as pd 
import sys 
import matplotlib 
import functools
import numpy as np
import time
import multiprocessing  
import random
#import spectrum
import KSTEST
import itertools
import os.path

from pylab import plot
from scipy import signal
from pandas import DataFrame, read_csv
from scipy import stats
#from spectrum import *
from datetime import timedelta, date, datetime

from multiprocessing import Pool

#Clean Cells That Have only 0 values for 
def CleanNullCells(ZoneDataFrame):
    for kpi in column_kpiselection:
        for cell in ZoneDataFrame['CellName'].unique():
            CelluleData = ZoneDataFrame.loc[ZoneDataFrame['CellName']==cell][['DAY_',kpi]]
            if(CelluleData[kpi] == 0).all():
                  ZoneDataFrame = ZoneDataFrame.loc[ZoneDataFrame['CellName'] != cell]
    return(ZoneDataFrame) 




def KSTestPerDay(cell1,cell2,kpi):
    cell1_kpi = alldata_kpis.loc[alldata_kpis['CellName']==cell1][['DAY_',kpi]]
    cell1_kpi['DAY_'] = pd.to_datetime(cell1_kpi['DAY_'],infer_datetime_format=True)    
    cell2_kpi = alldata_kpis.loc[alldata_kpis['CellName']==cell2][['DAY_',kpi]]
    cell2_kpi['DAY_'] = pd.to_datetime(cell2_kpi['DAY_'],infer_datetime_format=True)
    
    KS = pd.DataFrame()
    for day in np.array([datetime(2018,8,7)+timedelta(days=i) for i in range(0,22)]):
        dayvalue = pd.DataFrame()
        dayvalue['Day'] = [day]
        mask1 = (cell1_kpi['DAY_'] >=day) & (cell1_kpi['DAY_'] <day+timedelta(days=1))
        mask2 = (cell2_kpi['DAY_'] >=day) & (cell2_kpi['DAY_'] <day+timedelta(days=1))

        dayvalue['pvalue'] = [stats.ks_2samp(cell1_kpi.loc[mask1][kpi],cell2_kpi.loc[mask2][kpi])[1]]
        KS = KS.append(dayvalue,ignore_index = True)
    return(KS)

def KSTest(ZoneDataFrame,cell1,cell2,kpiList,dayList, wh = True):
    auxList = [kpi for kpi in kpiList]
    auxList.append('DAY_')
    cell1_kpi = ZoneDataFrame.loc[ZoneDataFrame['CellName']==cell1][auxList]
    cell1_kpi['DAY_'] = pd.to_datetime(cell1_kpi['DAY_'],infer_datetime_format=True)
    cell1_kpi = cell1_kpi.set_index('DAY_')
    cell2_kpi = ZoneDataFrame.loc[ZoneDataFrame['CellName']==cell2][auxList]
    cell2_kpi['DAY_'] = pd.to_datetime(cell2_kpi['DAY_'],infer_datetime_format=True)
    cell2_kpi = cell2_kpi.set_index('DAY_')
    out = {}
    if wh:
        cell1_kpi = cell1_kpi.between_time('7:00','23:00')
        cell1_kpi['DAY_'] = cell1_kpi.index
        cell1_kpi['DAY_'] = pd.to_datetime(cell1_kpi['DAY_'],infer_datetime_format=True)
        cell2_kpi = cell2_kpi.between_time('7:00','23:00')
        cell2_kpi['DAY_'] = cell2_kpi.index
        cell2_kpi['DAY_'] = pd.to_datetime(cell2_kpi['DAY_'],infer_datetime_format=True)
    for day in dayList:
        out[day] = {}
        mask1 = (cell1_kpi['DAY_'] >=day) & (cell1_kpi['DAY_'] <day+timedelta(days=1) ) 
        mask2 = (cell2_kpi['DAY_'] >=day) & (cell2_kpi['DAY_'] <day+timedelta(days=1) )
        for kpi in kpiList:
            pvalue = [stats.ks_2samp(cell1_kpi.loc[mask1][kpi],cell2_kpi.loc[mask2][kpi])[1]]
            out[day][kpi] = pvalue
    return(out)

def KSTestDay(ZoneDataFrame,cell1,cell2,kpi,day):
    cell1_kpi = ZoneDataFrame.loc[ZoneDataFrame['CellName']==cell1][['DAY_',kpi]]
    cell1_kpi['DAY_'] = pd.to_datetime(cell1_kpi['DAY_'],infer_datetime_format=True)
    cell1_kpi.loc[cell1_kpi['DAY_'] ==day]
    cell2_kpi = ZoneDataFrame.loc[ZoneDataFrame['CellName']==cell2][['DAY_',kpi]]
    cell2_kpi['DAY_'] = pd.to_datetime(cell2_kpi['DAY_'],infer_datetime_format=True)
    cell2_kpi.loc[cell2_kpi['DAY_'] ==day]
    return(stats.ks_2samp(cell1_kpi[kpi],cell2_kpi[kpi])[1])



def KSTestPerWeekDay(cell1,cell2,kpi):
    cell1_kpi = alldata_kpis.loc[alldata_kpis['CellName']==cell1][['DAY_',kpi]]   
    cell1_kpi['DAY_'] = pd.to_datetime(cell1_kpi['DAY_'],infer_datetime_format=True)
    cell2_kpi = alldata_kpis.loc[alldata_kpis['CellName']==cell2][['DAY_',kpi]]
    cell2_kpi['DAY_'] = pd.to_datetime(cell2_kpi['DAY_'],infer_datetime_format=True)
  
    KS = pd.DataFrame()
    for day in range(0,7):
        dayvalue = pd.DataFrame()
        dayvalue['Day'] = [day]
        mask1 = (cell1_kpi['DAY_'].dt.dayofweek==day)
        mask2 = (cell2_kpi['DAY_'].dt.dayofweek==day)
        dayvalue['pvalue'] = [stats.ks_2samp(cell1_kpi.loc[mask1][kpi],cell2_kpi.loc[mask2][kpi])[1]]
        KS = KS.append(dayvalue,ignore_index = True)
    return(KS)

def KSTestAllCellsPerDayAverage(ZoneDataFrame,kpi):
    KS = pd.DataFrame()
    alreadyDoneCouples = []
    for cell1 in ZoneDataFrame['CellName'].unique():
        for cell2 in ZoneDataFrame['CellName'].unique():
            if cell1 == cell2:
                KS.at[str(cell1),str(cell2)] = float(1)
            elif [cell2,cell1] in alreadyDoneCouples:
                KS.at[str(cell1),str(cell2)] = KS.loc[str(cell2)][str(cell1)]
            else:
                avg = KSTestPerDay(cell1,cell2,kpi)['pvalue'].mean()
                KS.at[cell1,cell2] = avg
                alreadyDoneCouples.append([cell1,cell2])
    return(KS)

def KSTestAllCellsDay(ZoneDataFrame,kpi,day):
    KS = pd.DataFrame()
    alreadyDoneCouples = []
    for cell1 in ZoneDataFrame['CellName'].unique():
        for cell2 in ZoneDataFrame['CellName'].unique():
            if cell1 == cell2:
                KS.at[str(cell1),str(cell2)] = float(1)
            elif [cell2,cell1] in alreadyDoneCouples:
                KS.at[str(cell1),str(cell2)] = KS.loc[str(cell2)][str(cell1)]
            else:
                avg = KSTestDay(ZoneDataFrame,cell1,cell2,kpi,day)
                KS.at[cell1,cell2] = avg
                alreadyDoneCouples.append([cell1,cell2])
    return(KS)

def KSTestAllCells(ZoneDataFrame,kpiList,dayList):
    out = {}
    for day in dayList:
        out[day]={}
        for kpi in kpiList:
            out[day][kpi] = pd.DataFrame()
    alreadyDoneCouples = []
    for cell1 in ZoneDataFrame['CellName'].unique():
        for cell2 in ZoneDataFrame['CellName'].unique():
            if cell1 == cell2:
                for day in dayList:
                    for kpi in kpiList:
                        out[day][kpi].at[str(cell1),str(cell2)] = float(1)
            elif [cell2,cell1] in alreadyDoneCouples:
                for day in dayList:
                    for kpi in kpiList:
                        out[day][kpi].at[str(cell1),str(cell2)] = out[day][kpi].loc[str(cell2)][str(cell1)]
            else:
                kstest = KSTest(ZoneDataFrame,cell1,cell2,kpiList,dayList)
                for day in kstest:
                    for kpi in kstest[day]:
                        out[day][kpi].at[cell1,cell2] = kstest[day][kpi][0]
                alreadyDoneCouples.append([cell1,cell2])
    return(out)

def KSTestAllCellsPerDayStd(ZoneDataFrame,kpi):
    KS = pd.DataFrame()
    alreadyDoneCouples = []
    for cell1 in ZoneDataFrame['CellName'].unique():
        for cell2 in ZoneDataFrame['CellName'].unique():
            if cell1 == cell2:
                KS.loc[str(cell1),str(cell2)] = float(0)
            elif [cell2,cell1] in alreadyDoneCouples:
                KS.at[str(cell1),str(cell2)] = KS.loc[str(cell2)][str(cell1)]
            else:
                std = KSTestPerDay(cell1,cell2,kpi)['pvalue'].std()
                KS.at[str(cell1),str(cell2)] = float(std)
                alreadyDoneCouples.append([cell1,cell2])
    return(KS)



def KSTestAllCellsPerWeekDayAverage(ZoneDataFrame,kpi):
    KS = pd.DataFrame()
    alreadyDoneCouples = []
    for cell1 in ZoneDataFrame['CellName'].unique():
        for cell2 in ZoneDataFrame['CellName'].unique():
            if cell1 == cell2:
                KS.at[str(cell1),str(cell2)] = float(1)
            elif [cell2,cell1] in alreadyDoneCouples:
                KS.at[str(cell1),str(cell2)] = KS.loc[str(cell2)][str(cell1)]
            else:
                avg = KSTestPerWeekDay(cell1,cell2,kpi)['pvalue'].mean()
                KS.at[cell1,cell2] = avg
                alreadyDoneCouples.append([cell1,cell2])
    return(KS)


def KSTestAllCellsPerWeekDayStd(ZoneDataFrame,kpi):
    KS = pd.DataFrame()
    alreadyDoneCouples = []
    for cell1 in ZoneDataFrame['CellName'].unique():
        for cell2 in ZoneDataFrame['CellName'].unique():
            if cell1 == cell2:
                KS.loc[str(cell1),str(cell2)] = float(0)
            elif [cell2,cell1] in alreadyDoneCouples:
                KS.at[str(cell1),str(cell2)] = KS.loc[str(cell2)][str(cell1)]
            else:
                std = KSTestPerWeekDay(cell1,cell2,kpi)['pvalue'].std()
                KS.at[str(cell1),str(cell2)] = float(std)
                alreadyDoneCouples.append([cell1,cell2])
    return(KS)



def getIdenticallyDistributedUnits(KSTestMatrix, alreadyDeletedCells = []): 
    count = 0
    totalpvalues = float(0)
    ToDeleteCell = 0
    for cell in KSTestMatrix.index.unique():
        A = np.array(KSTestMatrix[cell].values)
        A = A[np.where(A<0.1)]
        if len(A)>0:
            if count < len(A):
                ToDeleteCell = cell 
                count = len(A)
                totalpvalues = sum(A)
            elif (count == len(A)) & (totalpvalues < float(sum(A))):
                ToDeleteCell = cell 
                count = len(A)
                totalpvalues = sum(A)
    if ToDeleteCell == 0:
        return([KSTestMatrix,alreadyDeletedCells])
    else:
        alreadyDeletedCells.append(ToDeleteCell)
        FiltredMatrix = KSTestMatrix.drop([ToDeleteCell], axis = 0)
        FiltredMatrix = FiltredMatrix.drop([ToDeleteCell], axis = 1)
        return(getIdenticallyDistributedUnits(FiltredMatrix,alreadyDeletedCells))
        

def getIdenticallyDistributedClusters(KSTestMatrix, partialResults=[]):
    Cluster = getIdenticallyDistributedUnits(KSTestMatrix,[])[0]
    DeletedCells = getIdenticallyDistributedUnits(KSTestMatrix,[])[1]
    partialResults.append(Cluster)
    if Cluster.size!=KSTestMatrix.size:
        Reste = KSTestMatrix.loc[DeletedCells][DeletedCells]
        return(getIdenticallyDistributedClusters(Reste,partialResults))
    else:
        return(partialResults)


def generateLabeledDataFromClusters(ClusterList,kpi):
    LabeledData = pd.DataFrame()
    Label = 0
    for cluster in ClusterList:
        for clustercell in cluster.index:
            LabeledData.loc[str(clustercell),str(kpi)+' Label'] = Label
        Label = Label + 1
    return(LabeledData)


def generateFeaturesFromCellList(CellList):
    FeaturesData = pd.DataFrame()
    for cell in CellList:
        FeaturesData.loc[cell,'Site'] = int(cell[1:len(cell)-1])
        if cell.startswith('D'):
            FeaturesData.loc[cell,'Tec'] = 0
            if cell[-1] =='A':
                FeaturesData.loc[cell,'Azimuth'] = 0
            elif cell[-1] =='B':
                FeaturesData.loc[cell,'Azimuth'] = 1
            elif cell[-1] =='C':
                FeaturesData.loc[cell,'Azimuth'] = 2    
        elif cell.startswith('L'):
            FeaturesData.loc[cell,'Tec'] = 1
            if cell[-1] =='A':
                FeaturesData.loc[cell,'Azimuth'] = 0
            elif cell[-1] =='B':
                FeaturesData.loc[cell,'Azimuth'] = 1
            elif cell[-1] =='C':
                FeaturesData.loc[cell,'Azimuth'] = 2
        elif cell.startswith('T'):
            FeaturesData.loc[cell,'Tec'] = 2
            if cell[-1] =='A':
                FeaturesData.loc[cell,'Azimuth'] = 0
            elif cell[-1] =='B':
                FeaturesData.loc[cell,'Azimuth'] = 1
            elif cell[-1] =='C':
                FeaturesData.loc[cell,'Azimuth'] = 2
    return(FeaturesData)


def generateKpiLabeledDataFromExcelKSTEST(excelFileLocation, kpiList):
    allKpiDataFrame = pd.DataFrame()
    i = 0
    for kpi in kpiList:
        kpiKSTEST = pd.read_excel(excelFileLocation, sheet_name = kpi)
        kpiClusters = getIdenticallyDistributedClusters(kpiKSTEST,[])
        kpiLabeledData = generateLabeledDataFromClusters(kpiClusters,kpi)
        if i == 0:
            cellFeatures = generateFeaturesFromCellList(kpiKSTEST.index)
            allKpiDataFrame = cellFeatures.join(kpiLabeledData)
            i = i+1
        else:
            allKpiDataFrame = allKpiDataFrame.join(kpiLabeledData) 
    return(allKpiDataFrame)

def generateKpiLabeledDataFromExcelKSTEST(excelFileLocation, kpiList):
    allKpiDataFrame = pd.DataFrame()
    time_struct={}
    i = 0
    for kpi in kpiList:
        kpiKSTEST = pd.read_excel(excelFileLocation, sheet_name = kpi)
        time_struct[kpi]={}
        time_struct[kpi]["delta_t"]=[]
        start_time = time.time()
        kpiClusters = getIdenticallyDistributedClusters(kpiKSTEST,[])
        end_time = time.time()
        time_struct[kpi]["delta_t"].append(end_time-start_time)
 
        kpiLabeledData = generateLabeledDataFromClusters(kpiClusters,kpi)
        if i == 0:
            cellFeatures = generateFeaturesFromCellList(kpiKSTEST.index)
            allKpiDataFrame = cellFeatures.join(kpiLabeledData)
            i = i+1
        else:
            allKpiDataFrame = allKpiDataFrame.join(kpiLabeledData) 
    return(allKpiDataFrame,time_struct)

def daterange(start_date, end_date):
    for n in range(int ((end_date - start_date).days)):
        yield start_date + timedelta(n)

def KSTestAllCellsPerDayAverageParallel(ZoneDataFrame,kpi):
    C = list(itertools.combinations(ZoneDataFrame['CellName'].unique(),2))
    A = [(ZoneDataFrame, c[0],c[1],kpi) for c in C]
    if __name__ == '__main__':
        from datetime import timedelta, date, datetime
        pool = Pool()
        t = time.time()
        print(time.time()-t)
        results = pool.starmap(KSTEST.KSTestPerDayAverageParallelFunc, A)
    del A
    del C
    return(results)

def KSTestAllCellsParallel(ZoneDataFrame,kpiList,dayList):
    C = list(itertools.combinations(ZoneDataFrame['CellName'].unique(),2))
    A = [(ZoneDataFrame, c[0],c[1],kpiList,dayList) for c in C]
    if __name__ == '__main__':
        from datetime import timedelta, date, datetime
        pool = Pool()
        t = time.time()
        print(time.time()-t)
        results = pool.starmap(KSTEST.KSTestParallelFunc, A)
    del A
    out = {}
    for day in dayList:
        out[day]={}
        for kpi in kpiList:
            out[day][kpi] = pd.DataFrame()
            
    i = 0        
    for c in C:
        r = results[i]
        i = i + 1
        for day in dayList:
                    for kpi in kpiList:
                        out[day][kpi].at[str(c[0]),str(c[0])] = float(1)
        for day in kstest:
                    for kpi in kstest[day]:
                        out[day][kpi].at[str(c[0]),str(c[1])] = r[day][kpi][0]
                        out[day][kpi].at[str(c[1]),str(c[0])] = r[day][kpi][0]
    return(out)

def buildKSTESTMatrixFromMPTEST(result):
    KS = pd.DataFrame()
    for res in result:
        cell1 = res.index.values[0]
        cell2 = res.columns.values[0]
        pvalue = res.loc[res.index.values[0]][res.columns.values[0]] 
        KS.at[str(cell1),str(cell2)] = pvalue
        KS.at[str(cell2),str(cell1)] = pvalue
    KS = KS.fillna(1)
    return(KS)

def Statistics(ZoneDataFrame,cell1,kpiList,dayList, wh = True):
    auxList = [kpi for kpi in kpiList]
    auxList.append('DAY_')
    cell1_kpi = ZoneDataFrame.loc[ZoneDataFrame['CellName']==cell1][auxList]
    cell1_kpi['DAY_'] = pd.to_datetime(cell1_kpi['DAY_'],infer_datetime_format=True)
    cell1_kpi = cell1_kpi.set_index('DAY_')
    out = pd.DataFrame()
    if wh:
        cell1_kpi = cell1_kpi.between_time('7:00','23:00')
        cell1_kpi['DAY_'] = cell1_kpi.index
        cell1_kpi['DAY_'] = pd.to_datetime(cell1_kpi['DAY_'],infer_datetime_format=True)
    for day in dayList:
        mask1 = (cell1_kpi['DAY_'] >=day) & (cell1_kpi['DAY_'] <day+timedelta(days=1) ) 
        for kpi in kpiList:
            out.at[str(day.date()),kpi+' mean'] = cell1_kpi.loc[mask1][kpi].mean()
            out.at[str(day.date()),kpi+' min'] = cell1_kpi.loc[mask1][kpi].min()
            out.at[str(day.date()),kpi+' max'] = cell1_kpi.loc[mask1][kpi].max()
               
    return(out)

print('Python version ' + sys.version)
print('Pandas version ' + pd.__version__)
print('Matplotlib version ' + matplotlib.__version__)
# Out:
# Python version 3.6.5 |Anaconda, Inc.| (default, Mar 29 2018, 13:32:41) [MSC v.1900 64 bit (AMD64)]
# Pandas version 0.23.0
# Matplotlib version 2.2.2
# Python version 3.6.5 |Anaconda, Inc.| (default, Mar 29 2018, 13:32:41) [MSC v.1900 64 bit (AMD64)]
# Pandas version 0.23.0
# Matplotlib version 2.2.2

# %%
def get_config(local_fic_conf, local_type):
    
    # print(local_type)
    liste_retour = []
    fic_config = open(local_fic_conf, "r")
    fin = 0 
    
    for line in fic_config:
        # print(line)
        line = line.replace("\n", "")        
        if line.find(local_type)>=0 and fin == 0 :
            # print("trouve")
            for line in fic_config :
                if line != "\n" and fin==0:
                    line = line.replace("\n", "")
                    liste_retour.append(line)
                else:
                    # print("fin trouve")
                    fin = 1
    fic_config.close()
    return(liste_retour)

def extract_list_from_file(local_file):
    loc_file = open(local_file, "r")
    data_read=[]
    for line in loc_file:
        line = line.replace("\n", "")
        data_read.append(line)
    loc_file.close()
    
    return (data_read)



###################
# global variables
###################
local_path = 'C:/Users/euripab/Desktop/ML Extraction/'
config_file = "config_python_max_jour.txt"

config_group = get_config(local_path + "/" + config_file, "config_group")

list_group=[]
inventaire_groupe=[]
inventaire_selected_struct=[]
if len(config_group)==1 :
    # extract group configuration
    list_group = extract_list_from_file(local_path + "/" + config_group[0])
    groupe_definition = {}
    for groupe_def in list_group :
        groupe_def2 = groupe_def.split(";")
        inventaire_selected_struct.append(groupe_def2[1])
        if not groupe_def2[0] in inventaire_groupe :
            inventaire_groupe.append(groupe_def2[0])
        groupe_definition[groupe_def2[1]] = groupe_def2[0]
        
# pour extraire les donnees de chaque groupe
# passer de liste a dataframe ()
array_list_group=[]
# pb : on garde les entetes dans les donnees -> a corriger
# les colonnes du dataframe ne sontpas nommees
for item in list_group:
    split_item = item.split(";")
    array_list_group.append(split_item)

df_list_group = pd.DataFrame(array_list_group)

# extraction des donnees du groupe residentiel
# df_list_group.loc[df_list_group[0]=='residentiel'][1]
# ResCellsKpi = alldata_kpis.loc[alldata_kpis['CellName'].isin(df_list_group.loc[df_list_group[0]=='residentiel'][1])]

# enlever 'TDC4GData', absent des donnees sources dans certains fichiers extraits de Ipod LTE
# kpiList = ['CQImoyen','TDC4GData','TrafficDataDL','DemandesVoix4G',
#            'VoIPqualitymeasinsuffstat','NombredeConnexionsPS','nbUEVoIPqualityOK',
#            'Nbrtentatives_QCi5__TEAVoix','TraficDataUL']
    
kpiList = ['CQImoyen','TraficDataDL','TraficDataUL',
           'VoIPqualitymeasinsuffstat','CROZON_NombredeConnexionsPS','nbUEVoIPqualityOK',
           'Nbrtentatives_QCi5__TEAVoix']

# %%
#P Value Average
computing_type = "single"
liste_data = os.listdir(local_path + "/data/")
time_struct={}
last_group = ''
for current_data in liste_data:
    current_group = current_data.replace("_D.xlsx", "")
    current_group = current_group.replace("_L.xlsx", "")
    current_group = current_group.replace("_T.xlsx", "")
    current_group = current_group.replace("_P.xlsx", "")
    current_group = current_group.replace(".xlsx", "")
    if current_group != last_group:
        time_struct={}
    last_group = current_group    
    ZoneCellsKpi=pd.read_excel(local_path + "/data/" + current_data)
    fic_result= local_path + "/KSTest/results1_Pvalues/" + "KSTest_" + current_data 
    fic_time= local_path + "/KSTest/compute_time/" + "time_KS_" + current_group + ".xlsx"
    writer_results = pd.ExcelWriter(fic_result)
    writer_time = pd.ExcelWriter(fic_time)
    if computing_type == 'single':
        time_struct[current_data]={}
        print("Compute KS_Single fichier : {}, groupe : {})".format(current_data, current_group))
        for kpi in kpiList:
            time_struct[current_data][kpi]={}
            time_struct[current_data][kpi]["delta_t"]=[]
            start_time = time.time()
            KpiPvalueMatrix = KSTestAllCellsPerDayAverage(ZoneCellsKpi,kpi)
            end_time = time.time()
            time_struct[current_data][kpi]["delta_t"].append(end_time-start_time)                
            KpiPvalueMatrix.to_excel(writer_results,sheet_name=kpi)
            df_time_struct = pd.DataFrame(time_struct)
            df_time_struct.to_excel(writer_time,sheet_name=current_group)
        writer_time.save()
        writer_results.save()

    elif computing_type == 'parallel':
        time_struct[current_data]={}
        print("Compute KS_parallel fichier : {}".format(current_data))
        for kpi in kpiList:
            time_struct[current_data][kpi]={}
            time_struct[current_data][kpi]["delta_t"]=[]
            start_time = time.time()
            results = KSTestAllCellsPerDayAverageParallel(ZoneCellsKpi,kpi)
            end_time = time.time()  
            KpiPvalueMatrix = buildKSTESTMatrixFromMPTEST(results)
            del results
            time_struct[current_data][kpi]["delta_t"].append(end_time-start_time)                 
            KpiPvalueMatrix.to_excel(writer_results,sheet_name=kpi)
            df_time_struct = pd.DataFrame(time_struct)
            df_time_struct.to_excel(writer_time,sheet_name=current_group)
        writer_time.save()
        writer_results.save()

# %%
#P value per Day
computing_type = "parallel"
liste_data = os.listdir(local_path + "/data/")
time_struct={}
last_group = ''
dayList = np.array([datetime(2018,8,7)+timedelta(days=i) for i in range(0,32)])
for current_data in liste_data:
    current_group = current_data.replace("_D.xlsx", "")
    current_group = current_group.replace("_L.xlsx", "")
    current_group = current_group.replace("_T.xlsx", "")
    current_group = current_group.replace("_P.xlsx", "")
    current_group = current_group.replace(".xlsx", "")
    if current_group != last_group:
        time_struct={}
    last_group = current_group    
    ZoneCellsKpi=pd.read_excel(local_path + "/data/" + current_data)
    if computing_type == 'single':
        time_struct[current_data]={}
        print("Compute KS_Single fichier : {}, groupe : {})".format(current_data, current_group))
        results = KSTestAllCells(ZoneCellsKpi,kpiList,dayList)
        for day in dayList:
            fic_result= local_path + "/KSTest/results3_PvaluesDays/" + "KSTest_"+str(day.date())+'_' + current_data 
            fic_time= local_path + "/KSTest/compute_time/" + "time_KS_" +str(day.date())+'_' +current_group + ".xlsx"
            writer_results = pd.ExcelWriter(fic_result)
            writer_time = pd.ExcelWriter(fic_time)
            for kpi in kpiList:
                KpiPvalueMatrix = results[day][kpi]
                KpiPvalueMatrix.to_excel(writer_results,sheet_name=kpi)
        writer_time.save()
        writer_results.save()

    elif computing_type == 'parallel':
        time_struct[current_data]={}
        print("Compute KS_Single fichier : {}, groupe : {})".format(current_data, current_group))
        results = KSTestAllCellsParallel(ZoneCellsKpi,kpiList,dayList)
        for day in dayList:
            fic_result= local_path + "/KSTest/results3_PvaluesDays/" + "KSTest_"+str(day.date())+'_' + current_data 
            fic_time= local_path + "/KSTest/compute_time/" + "time_KS_" +str(day.date())+'_' +current_group + ".xlsx"
            writer_results = pd.ExcelWriter(fic_result)
            writer_time = pd.ExcelWriter(fic_time)
            for kpi in kpiList:
                KpiPvalueMatrix = results[day][kpi]
                KpiPvalueMatrix.to_excel(writer_results,sheet_name=kpi)
        writer_time.save()
        writer_results.save()
# Out:
# Compute KS_Single fichier : all.xlsx, groupe : all)
# 0.0

# %%
#Clustering
liste_data = os.listdir(local_path + "/KSTest/results3_PvaluesDays/")
time_struct={}
last_group = ''
for current_data in liste_data:
    current_group = current_data.replace("_D.xlsx", "")
    current_group = current_group.replace("_L.xlsx", "")
    current_group = current_group.replace("_T.xlsx", "")
    current_group = current_group.replace("_P.xlsx", "")
    current_group = current_group.replace(".xlsx", "")
    if current_group != last_group:
        time_struct={}
    last_group = current_group    

    fic_result= local_path + "/KSTest/results4_ClustersDays/" + "clustering_" + current_data
    fic_time= local_path + "/KSTest/compute_time/" + "time_clustering_" + current_group + ".xlsx"
    writer_results = pd.ExcelWriter(fic_result)
    writer_time = pd.ExcelWriter(fic_time)
    print("Compute Clustering fichier : {}, groupe : {})".format(current_data, current_group[:30]))
    path = local_path + "/KSTest/results3_PvaluesDays/" +current_data
    output = generateKpiLabeledDataFromExcelKSTEST(path, kpiList)
    time_struct[current_data]=output[1]
    output[0].to_excel(writer_results,sheet_name=current_group[:30])
    df_time_struct = pd.DataFrame(time_struct)
    df_time_struct.to_excel(writer_time,sheet_name=current_group[:30])
    writer_time.save()
    writer_results.save()
# Out:
# Compute Clustering fichier : KSTest_2018-08-07_all.xlsx, groupe : KSTest_2018-08-07_all)
# Compute Clustering fichier : KSTest_2018-08-07_Chatelet_les_halles.xlsx, groupe : KSTest_2018-08-07_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-07_Chatelet_les_halles_D.xlsx, groupe : KSTest_2018-08-07_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-07_Chatelet_les_halles_L.xlsx, groupe : KSTest_2018-08-07_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-07_Chatelet_les_halles_P.xlsx, groupe : KSTest_2018-08-07_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-07_Chatelet_les_halles_T.xlsx, groupe : KSTest_2018-08-07_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-07_concorde.xlsx, groupe : KSTest_2018-08-07_concorde)
# Compute Clustering fichier : KSTest_2018-08-07_concorde_D.xlsx, groupe : KSTest_2018-08-07_concorde)
# Compute Clustering fichier : KSTest_2018-08-07_concorde_L.xlsx, groupe : KSTest_2018-08-07_concorde)
# Compute Clustering fichier : KSTest_2018-08-07_concorde_P.xlsx, groupe : KSTest_2018-08-07_concorde)
# Compute Clustering fichier : KSTest_2018-08-07_concorde_T.xlsx, groupe : KSTest_2018-08-07_concorde)
# Compute Clustering fichier : KSTest_2018-08-07_Gare_St_lazare.xlsx, groupe : KSTest_2018-08-07_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-07_Gare_St_lazare_D.xlsx, groupe : KSTest_2018-08-07_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-07_Gare_St_lazare_L.xlsx, groupe : KSTest_2018-08-07_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-07_Gare_St_lazare_P.xlsx, groupe : KSTest_2018-08-07_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-07_Gare_St_lazare_T.xlsx, groupe : KSTest_2018-08-07_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-07_residentiel.xlsx, groupe : KSTest_2018-08-07_residentiel)
# Compute Clustering fichier : KSTest_2018-08-07_residentiel_D.xlsx, groupe : KSTest_2018-08-07_residentiel)
# Compute Clustering fichier : KSTest_2018-08-07_residentiel_L.xlsx, groupe : KSTest_2018-08-07_residentiel)
# Compute Clustering fichier : KSTest_2018-08-07_residentiel_P.xlsx, groupe : KSTest_2018-08-07_residentiel)
# Compute Clustering fichier : KSTest_2018-08-07_residentiel_T.xlsx, groupe : KSTest_2018-08-07_residentiel)
# Compute Clustering fichier : KSTest_2018-08-07_rive_droite_seine.xlsx, groupe : KSTest_2018-08-07_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-07_rive_droite_seine_D.xlsx, groupe : KSTest_2018-08-07_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-07_rive_droite_seine_L.xlsx, groupe : KSTest_2018-08-07_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-07_rive_droite_seine_P.xlsx, groupe : KSTest_2018-08-07_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-07_rive_droite_seine_T.xlsx, groupe : KSTest_2018-08-07_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-08_all.xlsx, groupe : KSTest_2018-08-08_all)
# Compute Clustering fichier : KSTest_2018-08-08_Chatelet_les_halles.xlsx, groupe : KSTest_2018-08-08_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-08_Chatelet_les_halles_D.xlsx, groupe : KSTest_2018-08-08_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-08_Chatelet_les_halles_L.xlsx, groupe : KSTest_2018-08-08_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-08_Chatelet_les_halles_P.xlsx, groupe : KSTest_2018-08-08_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-08_Chatelet_les_halles_T.xlsx, groupe : KSTest_2018-08-08_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-08_concorde.xlsx, groupe : KSTest_2018-08-08_concorde)
# Compute Clustering fichier : KSTest_2018-08-08_concorde_D.xlsx, groupe : KSTest_2018-08-08_concorde)
# Compute Clustering fichier : KSTest_2018-08-08_concorde_L.xlsx, groupe : KSTest_2018-08-08_concorde)
# Compute Clustering fichier : KSTest_2018-08-08_concorde_P.xlsx, groupe : KSTest_2018-08-08_concorde)
# Compute Clustering fichier : KSTest_2018-08-08_concorde_T.xlsx, groupe : KSTest_2018-08-08_concorde)
# Compute Clustering fichier : KSTest_2018-08-08_Gare_St_lazare.xlsx, groupe : KSTest_2018-08-08_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-08_Gare_St_lazare_D.xlsx, groupe : KSTest_2018-08-08_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-08_Gare_St_lazare_L.xlsx, groupe : KSTest_2018-08-08_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-08_Gare_St_lazare_P.xlsx, groupe : KSTest_2018-08-08_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-08_Gare_St_lazare_T.xlsx, groupe : KSTest_2018-08-08_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-08_residentiel.xlsx, groupe : KSTest_2018-08-08_residentiel)
# Compute Clustering fichier : KSTest_2018-08-08_residentiel_D.xlsx, groupe : KSTest_2018-08-08_residentiel)
# Compute Clustering fichier : KSTest_2018-08-08_residentiel_L.xlsx, groupe : KSTest_2018-08-08_residentiel)
# Compute Clustering fichier : KSTest_2018-08-08_residentiel_P.xlsx, groupe : KSTest_2018-08-08_residentiel)
# Compute Clustering fichier : KSTest_2018-08-08_residentiel_T.xlsx, groupe : KSTest_2018-08-08_residentiel)
# Compute Clustering fichier : KSTest_2018-08-08_rive_droite_seine.xlsx, groupe : KSTest_2018-08-08_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-08_rive_droite_seine_D.xlsx, groupe : KSTest_2018-08-08_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-08_rive_droite_seine_L.xlsx, groupe : KSTest_2018-08-08_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-08_rive_droite_seine_P.xlsx, groupe : KSTest_2018-08-08_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-08_rive_droite_seine_T.xlsx, groupe : KSTest_2018-08-08_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-09_all.xlsx, groupe : KSTest_2018-08-09_all)
# Compute Clustering fichier : KSTest_2018-08-09_Chatelet_les_halles.xlsx, groupe : KSTest_2018-08-09_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-09_Chatelet_les_halles_D.xlsx, groupe : KSTest_2018-08-09_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-09_Chatelet_les_halles_L.xlsx, groupe : KSTest_2018-08-09_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-09_Chatelet_les_halles_P.xlsx, groupe : KSTest_2018-08-09_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-09_Chatelet_les_halles_T.xlsx, groupe : KSTest_2018-08-09_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-09_concorde.xlsx, groupe : KSTest_2018-08-09_concorde)
# Compute Clustering fichier : KSTest_2018-08-09_concorde_D.xlsx, groupe : KSTest_2018-08-09_concorde)
# Compute Clustering fichier : KSTest_2018-08-09_concorde_L.xlsx, groupe : KSTest_2018-08-09_concorde)
# Compute Clustering fichier : KSTest_2018-08-09_concorde_P.xlsx, groupe : KSTest_2018-08-09_concorde)
# Compute Clustering fichier : KSTest_2018-08-09_concorde_T.xlsx, groupe : KSTest_2018-08-09_concorde)
# Compute Clustering fichier : KSTest_2018-08-09_Gare_St_lazare.xlsx, groupe : KSTest_2018-08-09_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-09_Gare_St_lazare_D.xlsx, groupe : KSTest_2018-08-09_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-09_Gare_St_lazare_L.xlsx, groupe : KSTest_2018-08-09_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-09_Gare_St_lazare_P.xlsx, groupe : KSTest_2018-08-09_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-09_Gare_St_lazare_T.xlsx, groupe : KSTest_2018-08-09_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-09_residentiel.xlsx, groupe : KSTest_2018-08-09_residentiel)
# Compute Clustering fichier : KSTest_2018-08-09_residentiel_D.xlsx, groupe : KSTest_2018-08-09_residentiel)
# Compute Clustering fichier : KSTest_2018-08-09_residentiel_L.xlsx, groupe : KSTest_2018-08-09_residentiel)
# Compute Clustering fichier : KSTest_2018-08-09_residentiel_P.xlsx, groupe : KSTest_2018-08-09_residentiel)
# Compute Clustering fichier : KSTest_2018-08-09_residentiel_T.xlsx, groupe : KSTest_2018-08-09_residentiel)
# Compute Clustering fichier : KSTest_2018-08-09_rive_droite_seine.xlsx, groupe : KSTest_2018-08-09_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-09_rive_droite_seine_D.xlsx, groupe : KSTest_2018-08-09_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-09_rive_droite_seine_L.xlsx, groupe : KSTest_2018-08-09_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-09_rive_droite_seine_P.xlsx, groupe : KSTest_2018-08-09_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-09_rive_droite_seine_T.xlsx, groupe : KSTest_2018-08-09_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-10_all.xlsx, groupe : KSTest_2018-08-10_all)
# Compute Clustering fichier : KSTest_2018-08-10_Chatelet_les_halles.xlsx, groupe : KSTest_2018-08-10_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-10_Chatelet_les_halles_D.xlsx, groupe : KSTest_2018-08-10_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-10_Chatelet_les_halles_L.xlsx, groupe : KSTest_2018-08-10_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-10_Chatelet_les_halles_P.xlsx, groupe : KSTest_2018-08-10_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-10_Chatelet_les_halles_T.xlsx, groupe : KSTest_2018-08-10_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-10_concorde.xlsx, groupe : KSTest_2018-08-10_concorde)
# Compute Clustering fichier : KSTest_2018-08-10_concorde_D.xlsx, groupe : KSTest_2018-08-10_concorde)
# Compute Clustering fichier : KSTest_2018-08-10_concorde_L.xlsx, groupe : KSTest_2018-08-10_concorde)
# Compute Clustering fichier : KSTest_2018-08-10_concorde_P.xlsx, groupe : KSTest_2018-08-10_concorde)
# Compute Clustering fichier : KSTest_2018-08-10_concorde_T.xlsx, groupe : KSTest_2018-08-10_concorde)
# Compute Clustering fichier : KSTest_2018-08-10_Gare_St_lazare.xlsx, groupe : KSTest_2018-08-10_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-10_Gare_St_lazare_D.xlsx, groupe : KSTest_2018-08-10_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-10_Gare_St_lazare_L.xlsx, groupe : KSTest_2018-08-10_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-10_Gare_St_lazare_P.xlsx, groupe : KSTest_2018-08-10_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-10_Gare_St_lazare_T.xlsx, groupe : KSTest_2018-08-10_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-10_residentiel.xlsx, groupe : KSTest_2018-08-10_residentiel)
# Compute Clustering fichier : KSTest_2018-08-10_residentiel_D.xlsx, groupe : KSTest_2018-08-10_residentiel)
# Compute Clustering fichier : KSTest_2018-08-10_residentiel_L.xlsx, groupe : KSTest_2018-08-10_residentiel)
# Compute Clustering fichier : KSTest_2018-08-10_residentiel_P.xlsx, groupe : KSTest_2018-08-10_residentiel)
# Compute Clustering fichier : KSTest_2018-08-10_residentiel_T.xlsx, groupe : KSTest_2018-08-10_residentiel)
# Compute Clustering fichier : KSTest_2018-08-10_rive_droite_seine.xlsx, groupe : KSTest_2018-08-10_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-10_rive_droite_seine_D.xlsx, groupe : KSTest_2018-08-10_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-10_rive_droite_seine_L.xlsx, groupe : KSTest_2018-08-10_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-10_rive_droite_seine_P.xlsx, groupe : KSTest_2018-08-10_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-10_rive_droite_seine_T.xlsx, groupe : KSTest_2018-08-10_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-11_all.xlsx, groupe : KSTest_2018-08-11_all)
# Compute Clustering fichier : KSTest_2018-08-11_Chatelet_les_halles.xlsx, groupe : KSTest_2018-08-11_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-11_Chatelet_les_halles_D.xlsx, groupe : KSTest_2018-08-11_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-11_Chatelet_les_halles_L.xlsx, groupe : KSTest_2018-08-11_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-11_Chatelet_les_halles_P.xlsx, groupe : KSTest_2018-08-11_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-11_Chatelet_les_halles_T.xlsx, groupe : KSTest_2018-08-11_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-11_concorde.xlsx, groupe : KSTest_2018-08-11_concorde)
# Compute Clustering fichier : KSTest_2018-08-11_concorde_D.xlsx, groupe : KSTest_2018-08-11_concorde)
# Compute Clustering fichier : KSTest_2018-08-11_concorde_L.xlsx, groupe : KSTest_2018-08-11_concorde)
# Compute Clustering fichier : KSTest_2018-08-11_concorde_P.xlsx, groupe : KSTest_2018-08-11_concorde)
# Compute Clustering fichier : KSTest_2018-08-11_concorde_T.xlsx, groupe : KSTest_2018-08-11_concorde)
# Compute Clustering fichier : KSTest_2018-08-11_Gare_St_lazare.xlsx, groupe : KSTest_2018-08-11_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-11_Gare_St_lazare_D.xlsx, groupe : KSTest_2018-08-11_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-11_Gare_St_lazare_L.xlsx, groupe : KSTest_2018-08-11_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-11_Gare_St_lazare_P.xlsx, groupe : KSTest_2018-08-11_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-11_Gare_St_lazare_T.xlsx, groupe : KSTest_2018-08-11_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-11_residentiel.xlsx, groupe : KSTest_2018-08-11_residentiel)
# Compute Clustering fichier : KSTest_2018-08-11_residentiel_D.xlsx, groupe : KSTest_2018-08-11_residentiel)
# Compute Clustering fichier : KSTest_2018-08-11_residentiel_L.xlsx, groupe : KSTest_2018-08-11_residentiel)
# Compute Clustering fichier : KSTest_2018-08-11_residentiel_P.xlsx, groupe : KSTest_2018-08-11_residentiel)
# Compute Clustering fichier : KSTest_2018-08-11_residentiel_T.xlsx, groupe : KSTest_2018-08-11_residentiel)
# Compute Clustering fichier : KSTest_2018-08-11_rive_droite_seine.xlsx, groupe : KSTest_2018-08-11_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-11_rive_droite_seine_D.xlsx, groupe : KSTest_2018-08-11_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-11_rive_droite_seine_L.xlsx, groupe : KSTest_2018-08-11_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-11_rive_droite_seine_P.xlsx, groupe : KSTest_2018-08-11_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-11_rive_droite_seine_T.xlsx, groupe : KSTest_2018-08-11_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-12_all.xlsx, groupe : KSTest_2018-08-12_all)
# Compute Clustering fichier : KSTest_2018-08-12_Chatelet_les_halles.xlsx, groupe : KSTest_2018-08-12_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-12_Chatelet_les_halles_D.xlsx, groupe : KSTest_2018-08-12_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-12_Chatelet_les_halles_L.xlsx, groupe : KSTest_2018-08-12_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-12_Chatelet_les_halles_P.xlsx, groupe : KSTest_2018-08-12_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-12_Chatelet_les_halles_T.xlsx, groupe : KSTest_2018-08-12_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-12_concorde.xlsx, groupe : KSTest_2018-08-12_concorde)
# Compute Clustering fichier : KSTest_2018-08-12_concorde_D.xlsx, groupe : KSTest_2018-08-12_concorde)
# Compute Clustering fichier : KSTest_2018-08-12_concorde_L.xlsx, groupe : KSTest_2018-08-12_concorde)
# Compute Clustering fichier : KSTest_2018-08-12_concorde_P.xlsx, groupe : KSTest_2018-08-12_concorde)
# Compute Clustering fichier : KSTest_2018-08-12_concorde_T.xlsx, groupe : KSTest_2018-08-12_concorde)
# Compute Clustering fichier : KSTest_2018-08-12_Gare_St_lazare.xlsx, groupe : KSTest_2018-08-12_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-12_Gare_St_lazare_D.xlsx, groupe : KSTest_2018-08-12_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-12_Gare_St_lazare_L.xlsx, groupe : KSTest_2018-08-12_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-12_Gare_St_lazare_P.xlsx, groupe : KSTest_2018-08-12_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-12_Gare_St_lazare_T.xlsx, groupe : KSTest_2018-08-12_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-12_residentiel.xlsx, groupe : KSTest_2018-08-12_residentiel)
# Compute Clustering fichier : KSTest_2018-08-12_residentiel_D.xlsx, groupe : KSTest_2018-08-12_residentiel)
# Compute Clustering fichier : KSTest_2018-08-12_residentiel_L.xlsx, groupe : KSTest_2018-08-12_residentiel)
# Compute Clustering fichier : KSTest_2018-08-12_residentiel_P.xlsx, groupe : KSTest_2018-08-12_residentiel)
# Compute Clustering fichier : KSTest_2018-08-12_residentiel_T.xlsx, groupe : KSTest_2018-08-12_residentiel)
# Compute Clustering fichier : KSTest_2018-08-12_rive_droite_seine.xlsx, groupe : KSTest_2018-08-12_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-12_rive_droite_seine_D.xlsx, groupe : KSTest_2018-08-12_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-12_rive_droite_seine_L.xlsx, groupe : KSTest_2018-08-12_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-12_rive_droite_seine_P.xlsx, groupe : KSTest_2018-08-12_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-12_rive_droite_seine_T.xlsx, groupe : KSTest_2018-08-12_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-13_all.xlsx, groupe : KSTest_2018-08-13_all)
# Compute Clustering fichier : KSTest_2018-08-13_Chatelet_les_halles.xlsx, groupe : KSTest_2018-08-13_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-13_Chatelet_les_halles_D.xlsx, groupe : KSTest_2018-08-13_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-13_Chatelet_les_halles_L.xlsx, groupe : KSTest_2018-08-13_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-13_Chatelet_les_halles_P.xlsx, groupe : KSTest_2018-08-13_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-13_Chatelet_les_halles_T.xlsx, groupe : KSTest_2018-08-13_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-13_concorde.xlsx, groupe : KSTest_2018-08-13_concorde)
# Compute Clustering fichier : KSTest_2018-08-13_concorde_D.xlsx, groupe : KSTest_2018-08-13_concorde)
# Compute Clustering fichier : KSTest_2018-08-13_concorde_L.xlsx, groupe : KSTest_2018-08-13_concorde)
# Compute Clustering fichier : KSTest_2018-08-13_concorde_P.xlsx, groupe : KSTest_2018-08-13_concorde)
# Compute Clustering fichier : KSTest_2018-08-13_concorde_T.xlsx, groupe : KSTest_2018-08-13_concorde)
# Compute Clustering fichier : KSTest_2018-08-13_Gare_St_lazare.xlsx, groupe : KSTest_2018-08-13_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-13_Gare_St_lazare_D.xlsx, groupe : KSTest_2018-08-13_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-13_Gare_St_lazare_L.xlsx, groupe : KSTest_2018-08-13_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-13_Gare_St_lazare_P.xlsx, groupe : KSTest_2018-08-13_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-13_Gare_St_lazare_T.xlsx, groupe : KSTest_2018-08-13_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-13_residentiel.xlsx, groupe : KSTest_2018-08-13_residentiel)
# Compute Clustering fichier : KSTest_2018-08-13_residentiel_D.xlsx, groupe : KSTest_2018-08-13_residentiel)
# Compute Clustering fichier : KSTest_2018-08-13_residentiel_L.xlsx, groupe : KSTest_2018-08-13_residentiel)
# Compute Clustering fichier : KSTest_2018-08-13_residentiel_P.xlsx, groupe : KSTest_2018-08-13_residentiel)
# Compute Clustering fichier : KSTest_2018-08-13_residentiel_T.xlsx, groupe : KSTest_2018-08-13_residentiel)
# Compute Clustering fichier : KSTest_2018-08-13_rive_droite_seine.xlsx, groupe : KSTest_2018-08-13_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-13_rive_droite_seine_D.xlsx, groupe : KSTest_2018-08-13_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-13_rive_droite_seine_L.xlsx, groupe : KSTest_2018-08-13_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-13_rive_droite_seine_P.xlsx, groupe : KSTest_2018-08-13_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-13_rive_droite_seine_T.xlsx, groupe : KSTest_2018-08-13_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-14_all.xlsx, groupe : KSTest_2018-08-14_all)
# Compute Clustering fichier : KSTest_2018-08-14_Chatelet_les_halles.xlsx, groupe : KSTest_2018-08-14_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-14_Chatelet_les_halles_D.xlsx, groupe : KSTest_2018-08-14_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-14_Chatelet_les_halles_L.xlsx, groupe : KSTest_2018-08-14_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-14_Chatelet_les_halles_P.xlsx, groupe : KSTest_2018-08-14_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-14_Chatelet_les_halles_T.xlsx, groupe : KSTest_2018-08-14_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-14_concorde.xlsx, groupe : KSTest_2018-08-14_concorde)
# Compute Clustering fichier : KSTest_2018-08-14_concorde_D.xlsx, groupe : KSTest_2018-08-14_concorde)
# Compute Clustering fichier : KSTest_2018-08-14_concorde_L.xlsx, groupe : KSTest_2018-08-14_concorde)
# Compute Clustering fichier : KSTest_2018-08-14_concorde_P.xlsx, groupe : KSTest_2018-08-14_concorde)
# Compute Clustering fichier : KSTest_2018-08-14_concorde_T.xlsx, groupe : KSTest_2018-08-14_concorde)
# Compute Clustering fichier : KSTest_2018-08-14_Gare_St_lazare.xlsx, groupe : KSTest_2018-08-14_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-14_Gare_St_lazare_D.xlsx, groupe : KSTest_2018-08-14_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-14_Gare_St_lazare_L.xlsx, groupe : KSTest_2018-08-14_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-14_Gare_St_lazare_P.xlsx, groupe : KSTest_2018-08-14_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-14_Gare_St_lazare_T.xlsx, groupe : KSTest_2018-08-14_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-14_residentiel.xlsx, groupe : KSTest_2018-08-14_residentiel)
# Compute Clustering fichier : KSTest_2018-08-14_residentiel_D.xlsx, groupe : KSTest_2018-08-14_residentiel)
# Compute Clustering fichier : KSTest_2018-08-14_residentiel_L.xlsx, groupe : KSTest_2018-08-14_residentiel)
# Compute Clustering fichier : KSTest_2018-08-14_residentiel_P.xlsx, groupe : KSTest_2018-08-14_residentiel)
# Compute Clustering fichier : KSTest_2018-08-14_residentiel_T.xlsx, groupe : KSTest_2018-08-14_residentiel)
# Compute Clustering fichier : KSTest_2018-08-14_rive_droite_seine.xlsx, groupe : KSTest_2018-08-14_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-14_rive_droite_seine_D.xlsx, groupe : KSTest_2018-08-14_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-14_rive_droite_seine_L.xlsx, groupe : KSTest_2018-08-14_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-14_rive_droite_seine_P.xlsx, groupe : KSTest_2018-08-14_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-14_rive_droite_seine_T.xlsx, groupe : KSTest_2018-08-14_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-15_all.xlsx, groupe : KSTest_2018-08-15_all)
# Compute Clustering fichier : KSTest_2018-08-15_Chatelet_les_halles.xlsx, groupe : KSTest_2018-08-15_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-15_Chatelet_les_halles_D.xlsx, groupe : KSTest_2018-08-15_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-15_Chatelet_les_halles_L.xlsx, groupe : KSTest_2018-08-15_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-15_Chatelet_les_halles_P.xlsx, groupe : KSTest_2018-08-15_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-15_Chatelet_les_halles_T.xlsx, groupe : KSTest_2018-08-15_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-15_concorde.xlsx, groupe : KSTest_2018-08-15_concorde)
# Compute Clustering fichier : KSTest_2018-08-15_concorde_D.xlsx, groupe : KSTest_2018-08-15_concorde)
# Compute Clustering fichier : KSTest_2018-08-15_concorde_L.xlsx, groupe : KSTest_2018-08-15_concorde)
# Compute Clustering fichier : KSTest_2018-08-15_concorde_P.xlsx, groupe : KSTest_2018-08-15_concorde)
# Compute Clustering fichier : KSTest_2018-08-15_concorde_T.xlsx, groupe : KSTest_2018-08-15_concorde)
# Compute Clustering fichier : KSTest_2018-08-15_Gare_St_lazare.xlsx, groupe : KSTest_2018-08-15_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-15_Gare_St_lazare_D.xlsx, groupe : KSTest_2018-08-15_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-15_Gare_St_lazare_L.xlsx, groupe : KSTest_2018-08-15_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-15_Gare_St_lazare_P.xlsx, groupe : KSTest_2018-08-15_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-15_Gare_St_lazare_T.xlsx, groupe : KSTest_2018-08-15_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-15_residentiel.xlsx, groupe : KSTest_2018-08-15_residentiel)
# Compute Clustering fichier : KSTest_2018-08-15_residentiel_D.xlsx, groupe : KSTest_2018-08-15_residentiel)
# Compute Clustering fichier : KSTest_2018-08-15_residentiel_L.xlsx, groupe : KSTest_2018-08-15_residentiel)
# Compute Clustering fichier : KSTest_2018-08-15_residentiel_P.xlsx, groupe : KSTest_2018-08-15_residentiel)
# Compute Clustering fichier : KSTest_2018-08-15_residentiel_T.xlsx, groupe : KSTest_2018-08-15_residentiel)
# Compute Clustering fichier : KSTest_2018-08-15_rive_droite_seine.xlsx, groupe : KSTest_2018-08-15_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-15_rive_droite_seine_D.xlsx, groupe : KSTest_2018-08-15_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-15_rive_droite_seine_L.xlsx, groupe : KSTest_2018-08-15_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-15_rive_droite_seine_P.xlsx, groupe : KSTest_2018-08-15_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-15_rive_droite_seine_T.xlsx, groupe : KSTest_2018-08-15_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-16_all.xlsx, groupe : KSTest_2018-08-16_all)
# Compute Clustering fichier : KSTest_2018-08-16_Chatelet_les_halles.xlsx, groupe : KSTest_2018-08-16_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-16_Chatelet_les_halles_D.xlsx, groupe : KSTest_2018-08-16_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-16_Chatelet_les_halles_L.xlsx, groupe : KSTest_2018-08-16_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-16_Chatelet_les_halles_P.xlsx, groupe : KSTest_2018-08-16_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-16_Chatelet_les_halles_T.xlsx, groupe : KSTest_2018-08-16_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-16_concorde.xlsx, groupe : KSTest_2018-08-16_concorde)
# Compute Clustering fichier : KSTest_2018-08-16_concorde_D.xlsx, groupe : KSTest_2018-08-16_concorde)
# Compute Clustering fichier : KSTest_2018-08-16_concorde_L.xlsx, groupe : KSTest_2018-08-16_concorde)
# Compute Clustering fichier : KSTest_2018-08-16_concorde_P.xlsx, groupe : KSTest_2018-08-16_concorde)
# Compute Clustering fichier : KSTest_2018-08-16_concorde_T.xlsx, groupe : KSTest_2018-08-16_concorde)
# Compute Clustering fichier : KSTest_2018-08-16_Gare_St_lazare.xlsx, groupe : KSTest_2018-08-16_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-16_Gare_St_lazare_D.xlsx, groupe : KSTest_2018-08-16_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-16_Gare_St_lazare_L.xlsx, groupe : KSTest_2018-08-16_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-16_Gare_St_lazare_P.xlsx, groupe : KSTest_2018-08-16_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-16_Gare_St_lazare_T.xlsx, groupe : KSTest_2018-08-16_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-16_residentiel.xlsx, groupe : KSTest_2018-08-16_residentiel)
# Compute Clustering fichier : KSTest_2018-08-16_residentiel_D.xlsx, groupe : KSTest_2018-08-16_residentiel)
# Compute Clustering fichier : KSTest_2018-08-16_residentiel_L.xlsx, groupe : KSTest_2018-08-16_residentiel)
# Compute Clustering fichier : KSTest_2018-08-16_residentiel_P.xlsx, groupe : KSTest_2018-08-16_residentiel)
# Compute Clustering fichier : KSTest_2018-08-16_residentiel_T.xlsx, groupe : KSTest_2018-08-16_residentiel)
# Compute Clustering fichier : KSTest_2018-08-16_rive_droite_seine.xlsx, groupe : KSTest_2018-08-16_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-16_rive_droite_seine_D.xlsx, groupe : KSTest_2018-08-16_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-16_rive_droite_seine_L.xlsx, groupe : KSTest_2018-08-16_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-16_rive_droite_seine_P.xlsx, groupe : KSTest_2018-08-16_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-16_rive_droite_seine_T.xlsx, groupe : KSTest_2018-08-16_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-17_all.xlsx, groupe : KSTest_2018-08-17_all)
# Compute Clustering fichier : KSTest_2018-08-17_Chatelet_les_halles.xlsx, groupe : KSTest_2018-08-17_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-17_Chatelet_les_halles_D.xlsx, groupe : KSTest_2018-08-17_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-17_Chatelet_les_halles_L.xlsx, groupe : KSTest_2018-08-17_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-17_Chatelet_les_halles_P.xlsx, groupe : KSTest_2018-08-17_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-17_Chatelet_les_halles_T.xlsx, groupe : KSTest_2018-08-17_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-17_concorde.xlsx, groupe : KSTest_2018-08-17_concorde)
# Compute Clustering fichier : KSTest_2018-08-17_concorde_D.xlsx, groupe : KSTest_2018-08-17_concorde)
# Compute Clustering fichier : KSTest_2018-08-17_concorde_L.xlsx, groupe : KSTest_2018-08-17_concorde)
# Compute Clustering fichier : KSTest_2018-08-17_concorde_P.xlsx, groupe : KSTest_2018-08-17_concorde)
# Compute Clustering fichier : KSTest_2018-08-17_concorde_T.xlsx, groupe : KSTest_2018-08-17_concorde)
# Compute Clustering fichier : KSTest_2018-08-17_Gare_St_lazare.xlsx, groupe : KSTest_2018-08-17_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-17_Gare_St_lazare_D.xlsx, groupe : KSTest_2018-08-17_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-17_Gare_St_lazare_L.xlsx, groupe : KSTest_2018-08-17_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-17_Gare_St_lazare_P.xlsx, groupe : KSTest_2018-08-17_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-17_Gare_St_lazare_T.xlsx, groupe : KSTest_2018-08-17_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-17_residentiel.xlsx, groupe : KSTest_2018-08-17_residentiel)
# Compute Clustering fichier : KSTest_2018-08-17_residentiel_D.xlsx, groupe : KSTest_2018-08-17_residentiel)
# Compute Clustering fichier : KSTest_2018-08-17_residentiel_L.xlsx, groupe : KSTest_2018-08-17_residentiel)
# Compute Clustering fichier : KSTest_2018-08-17_residentiel_P.xlsx, groupe : KSTest_2018-08-17_residentiel)
# Compute Clustering fichier : KSTest_2018-08-17_residentiel_T.xlsx, groupe : KSTest_2018-08-17_residentiel)
# Compute Clustering fichier : KSTest_2018-08-17_rive_droite_seine.xlsx, groupe : KSTest_2018-08-17_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-17_rive_droite_seine_D.xlsx, groupe : KSTest_2018-08-17_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-17_rive_droite_seine_L.xlsx, groupe : KSTest_2018-08-17_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-17_rive_droite_seine_P.xlsx, groupe : KSTest_2018-08-17_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-17_rive_droite_seine_T.xlsx, groupe : KSTest_2018-08-17_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-18_all.xlsx, groupe : KSTest_2018-08-18_all)
# Compute Clustering fichier : KSTest_2018-08-18_Chatelet_les_halles.xlsx, groupe : KSTest_2018-08-18_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-18_Chatelet_les_halles_D.xlsx, groupe : KSTest_2018-08-18_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-18_Chatelet_les_halles_L.xlsx, groupe : KSTest_2018-08-18_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-18_Chatelet_les_halles_P.xlsx, groupe : KSTest_2018-08-18_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-18_Chatelet_les_halles_T.xlsx, groupe : KSTest_2018-08-18_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-18_concorde.xlsx, groupe : KSTest_2018-08-18_concorde)
# Compute Clustering fichier : KSTest_2018-08-18_concorde_D.xlsx, groupe : KSTest_2018-08-18_concorde)
# Compute Clustering fichier : KSTest_2018-08-18_concorde_L.xlsx, groupe : KSTest_2018-08-18_concorde)
# Compute Clustering fichier : KSTest_2018-08-18_concorde_P.xlsx, groupe : KSTest_2018-08-18_concorde)
# Compute Clustering fichier : KSTest_2018-08-18_concorde_T.xlsx, groupe : KSTest_2018-08-18_concorde)
# Compute Clustering fichier : KSTest_2018-08-18_Gare_St_lazare.xlsx, groupe : KSTest_2018-08-18_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-18_Gare_St_lazare_D.xlsx, groupe : KSTest_2018-08-18_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-18_Gare_St_lazare_L.xlsx, groupe : KSTest_2018-08-18_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-18_Gare_St_lazare_P.xlsx, groupe : KSTest_2018-08-18_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-18_Gare_St_lazare_T.xlsx, groupe : KSTest_2018-08-18_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-18_residentiel.xlsx, groupe : KSTest_2018-08-18_residentiel)
# Compute Clustering fichier : KSTest_2018-08-18_residentiel_D.xlsx, groupe : KSTest_2018-08-18_residentiel)
# Compute Clustering fichier : KSTest_2018-08-18_residentiel_L.xlsx, groupe : KSTest_2018-08-18_residentiel)
# Compute Clustering fichier : KSTest_2018-08-18_residentiel_P.xlsx, groupe : KSTest_2018-08-18_residentiel)
# Compute Clustering fichier : KSTest_2018-08-18_residentiel_T.xlsx, groupe : KSTest_2018-08-18_residentiel)
# Compute Clustering fichier : KSTest_2018-08-18_rive_droite_seine.xlsx, groupe : KSTest_2018-08-18_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-18_rive_droite_seine_D.xlsx, groupe : KSTest_2018-08-18_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-18_rive_droite_seine_L.xlsx, groupe : KSTest_2018-08-18_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-18_rive_droite_seine_P.xlsx, groupe : KSTest_2018-08-18_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-18_rive_droite_seine_T.xlsx, groupe : KSTest_2018-08-18_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-19_all.xlsx, groupe : KSTest_2018-08-19_all)
# Compute Clustering fichier : KSTest_2018-08-19_Chatelet_les_halles.xlsx, groupe : KSTest_2018-08-19_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-19_Chatelet_les_halles_D.xlsx, groupe : KSTest_2018-08-19_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-19_Chatelet_les_halles_L.xlsx, groupe : KSTest_2018-08-19_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-19_Chatelet_les_halles_P.xlsx, groupe : KSTest_2018-08-19_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-19_Chatelet_les_halles_T.xlsx, groupe : KSTest_2018-08-19_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-19_concorde.xlsx, groupe : KSTest_2018-08-19_concorde)
# Compute Clustering fichier : KSTest_2018-08-19_concorde_D.xlsx, groupe : KSTest_2018-08-19_concorde)
# Compute Clustering fichier : KSTest_2018-08-19_concorde_L.xlsx, groupe : KSTest_2018-08-19_concorde)
# Compute Clustering fichier : KSTest_2018-08-19_concorde_P.xlsx, groupe : KSTest_2018-08-19_concorde)
# Compute Clustering fichier : KSTest_2018-08-19_concorde_T.xlsx, groupe : KSTest_2018-08-19_concorde)
# Compute Clustering fichier : KSTest_2018-08-19_Gare_St_lazare.xlsx, groupe : KSTest_2018-08-19_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-19_Gare_St_lazare_D.xlsx, groupe : KSTest_2018-08-19_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-19_Gare_St_lazare_L.xlsx, groupe : KSTest_2018-08-19_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-19_Gare_St_lazare_P.xlsx, groupe : KSTest_2018-08-19_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-19_Gare_St_lazare_T.xlsx, groupe : KSTest_2018-08-19_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-19_residentiel.xlsx, groupe : KSTest_2018-08-19_residentiel)
# Compute Clustering fichier : KSTest_2018-08-19_residentiel_D.xlsx, groupe : KSTest_2018-08-19_residentiel)
# Compute Clustering fichier : KSTest_2018-08-19_residentiel_L.xlsx, groupe : KSTest_2018-08-19_residentiel)
# Compute Clustering fichier : KSTest_2018-08-19_residentiel_P.xlsx, groupe : KSTest_2018-08-19_residentiel)
# Compute Clustering fichier : KSTest_2018-08-19_residentiel_T.xlsx, groupe : KSTest_2018-08-19_residentiel)
# Compute Clustering fichier : KSTest_2018-08-19_rive_droite_seine.xlsx, groupe : KSTest_2018-08-19_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-19_rive_droite_seine_D.xlsx, groupe : KSTest_2018-08-19_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-19_rive_droite_seine_L.xlsx, groupe : KSTest_2018-08-19_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-19_rive_droite_seine_P.xlsx, groupe : KSTest_2018-08-19_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-19_rive_droite_seine_T.xlsx, groupe : KSTest_2018-08-19_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-20_all.xlsx, groupe : KSTest_2018-08-20_all)
# Compute Clustering fichier : KSTest_2018-08-20_Chatelet_les_halles.xlsx, groupe : KSTest_2018-08-20_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-20_Chatelet_les_halles_D.xlsx, groupe : KSTest_2018-08-20_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-20_Chatelet_les_halles_L.xlsx, groupe : KSTest_2018-08-20_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-20_Chatelet_les_halles_P.xlsx, groupe : KSTest_2018-08-20_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-20_Chatelet_les_halles_T.xlsx, groupe : KSTest_2018-08-20_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-20_concorde.xlsx, groupe : KSTest_2018-08-20_concorde)
# Compute Clustering fichier : KSTest_2018-08-20_concorde_D.xlsx, groupe : KSTest_2018-08-20_concorde)
# Compute Clustering fichier : KSTest_2018-08-20_concorde_L.xlsx, groupe : KSTest_2018-08-20_concorde)
# Compute Clustering fichier : KSTest_2018-08-20_concorde_P.xlsx, groupe : KSTest_2018-08-20_concorde)
# Compute Clustering fichier : KSTest_2018-08-20_concorde_T.xlsx, groupe : KSTest_2018-08-20_concorde)
# Compute Clustering fichier : KSTest_2018-08-20_Gare_St_lazare.xlsx, groupe : KSTest_2018-08-20_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-20_Gare_St_lazare_D.xlsx, groupe : KSTest_2018-08-20_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-20_Gare_St_lazare_L.xlsx, groupe : KSTest_2018-08-20_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-20_Gare_St_lazare_P.xlsx, groupe : KSTest_2018-08-20_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-20_Gare_St_lazare_T.xlsx, groupe : KSTest_2018-08-20_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-20_residentiel.xlsx, groupe : KSTest_2018-08-20_residentiel)
# Compute Clustering fichier : KSTest_2018-08-20_residentiel_D.xlsx, groupe : KSTest_2018-08-20_residentiel)
# Compute Clustering fichier : KSTest_2018-08-20_residentiel_L.xlsx, groupe : KSTest_2018-08-20_residentiel)
# Compute Clustering fichier : KSTest_2018-08-20_residentiel_P.xlsx, groupe : KSTest_2018-08-20_residentiel)
# Compute Clustering fichier : KSTest_2018-08-20_residentiel_T.xlsx, groupe : KSTest_2018-08-20_residentiel)
# Compute Clustering fichier : KSTest_2018-08-20_rive_droite_seine.xlsx, groupe : KSTest_2018-08-20_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-20_rive_droite_seine_D.xlsx, groupe : KSTest_2018-08-20_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-20_rive_droite_seine_L.xlsx, groupe : KSTest_2018-08-20_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-20_rive_droite_seine_P.xlsx, groupe : KSTest_2018-08-20_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-20_rive_droite_seine_T.xlsx, groupe : KSTest_2018-08-20_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-21_all.xlsx, groupe : KSTest_2018-08-21_all)
# Compute Clustering fichier : KSTest_2018-08-21_Chatelet_les_halles.xlsx, groupe : KSTest_2018-08-21_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-21_Chatelet_les_halles_D.xlsx, groupe : KSTest_2018-08-21_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-21_Chatelet_les_halles_L.xlsx, groupe : KSTest_2018-08-21_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-21_Chatelet_les_halles_P.xlsx, groupe : KSTest_2018-08-21_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-21_Chatelet_les_halles_T.xlsx, groupe : KSTest_2018-08-21_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-21_concorde.xlsx, groupe : KSTest_2018-08-21_concorde)
# Compute Clustering fichier : KSTest_2018-08-21_concorde_D.xlsx, groupe : KSTest_2018-08-21_concorde)
# Compute Clustering fichier : KSTest_2018-08-21_concorde_L.xlsx, groupe : KSTest_2018-08-21_concorde)
# Compute Clustering fichier : KSTest_2018-08-21_concorde_P.xlsx, groupe : KSTest_2018-08-21_concorde)
# Compute Clustering fichier : KSTest_2018-08-21_concorde_T.xlsx, groupe : KSTest_2018-08-21_concorde)
# Compute Clustering fichier : KSTest_2018-08-21_Gare_St_lazare.xlsx, groupe : KSTest_2018-08-21_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-21_Gare_St_lazare_D.xlsx, groupe : KSTest_2018-08-21_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-21_Gare_St_lazare_L.xlsx, groupe : KSTest_2018-08-21_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-21_Gare_St_lazare_P.xlsx, groupe : KSTest_2018-08-21_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-21_Gare_St_lazare_T.xlsx, groupe : KSTest_2018-08-21_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-21_residentiel.xlsx, groupe : KSTest_2018-08-21_residentiel)
# Compute Clustering fichier : KSTest_2018-08-21_residentiel_D.xlsx, groupe : KSTest_2018-08-21_residentiel)
# Compute Clustering fichier : KSTest_2018-08-21_residentiel_L.xlsx, groupe : KSTest_2018-08-21_residentiel)
# Compute Clustering fichier : KSTest_2018-08-21_residentiel_P.xlsx, groupe : KSTest_2018-08-21_residentiel)
# Compute Clustering fichier : KSTest_2018-08-21_residentiel_T.xlsx, groupe : KSTest_2018-08-21_residentiel)
# Compute Clustering fichier : KSTest_2018-08-21_rive_droite_seine.xlsx, groupe : KSTest_2018-08-21_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-21_rive_droite_seine_D.xlsx, groupe : KSTest_2018-08-21_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-21_rive_droite_seine_L.xlsx, groupe : KSTest_2018-08-21_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-21_rive_droite_seine_P.xlsx, groupe : KSTest_2018-08-21_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-21_rive_droite_seine_T.xlsx, groupe : KSTest_2018-08-21_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-22_all.xlsx, groupe : KSTest_2018-08-22_all)
# Compute Clustering fichier : KSTest_2018-08-22_Chatelet_les_halles.xlsx, groupe : KSTest_2018-08-22_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-22_Chatelet_les_halles_D.xlsx, groupe : KSTest_2018-08-22_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-22_Chatelet_les_halles_L.xlsx, groupe : KSTest_2018-08-22_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-22_Chatelet_les_halles_P.xlsx, groupe : KSTest_2018-08-22_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-22_Chatelet_les_halles_T.xlsx, groupe : KSTest_2018-08-22_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-22_concorde.xlsx, groupe : KSTest_2018-08-22_concorde)
# Compute Clustering fichier : KSTest_2018-08-22_concorde_D.xlsx, groupe : KSTest_2018-08-22_concorde)
# Compute Clustering fichier : KSTest_2018-08-22_concorde_L.xlsx, groupe : KSTest_2018-08-22_concorde)
# Compute Clustering fichier : KSTest_2018-08-22_concorde_P.xlsx, groupe : KSTest_2018-08-22_concorde)
# Compute Clustering fichier : KSTest_2018-08-22_concorde_T.xlsx, groupe : KSTest_2018-08-22_concorde)
# Compute Clustering fichier : KSTest_2018-08-22_Gare_St_lazare.xlsx, groupe : KSTest_2018-08-22_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-22_Gare_St_lazare_D.xlsx, groupe : KSTest_2018-08-22_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-22_Gare_St_lazare_L.xlsx, groupe : KSTest_2018-08-22_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-22_Gare_St_lazare_P.xlsx, groupe : KSTest_2018-08-22_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-22_Gare_St_lazare_T.xlsx, groupe : KSTest_2018-08-22_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-22_residentiel.xlsx, groupe : KSTest_2018-08-22_residentiel)
# Compute Clustering fichier : KSTest_2018-08-22_residentiel_D.xlsx, groupe : KSTest_2018-08-22_residentiel)
# Compute Clustering fichier : KSTest_2018-08-22_residentiel_L.xlsx, groupe : KSTest_2018-08-22_residentiel)
# Compute Clustering fichier : KSTest_2018-08-22_residentiel_P.xlsx, groupe : KSTest_2018-08-22_residentiel)
# Compute Clustering fichier : KSTest_2018-08-22_residentiel_T.xlsx, groupe : KSTest_2018-08-22_residentiel)
# Compute Clustering fichier : KSTest_2018-08-22_rive_droite_seine.xlsx, groupe : KSTest_2018-08-22_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-22_rive_droite_seine_D.xlsx, groupe : KSTest_2018-08-22_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-22_rive_droite_seine_L.xlsx, groupe : KSTest_2018-08-22_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-22_rive_droite_seine_P.xlsx, groupe : KSTest_2018-08-22_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-22_rive_droite_seine_T.xlsx, groupe : KSTest_2018-08-22_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-23_all.xlsx, groupe : KSTest_2018-08-23_all)
# Compute Clustering fichier : KSTest_2018-08-23_Chatelet_les_halles.xlsx, groupe : KSTest_2018-08-23_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-23_Chatelet_les_halles_D.xlsx, groupe : KSTest_2018-08-23_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-23_Chatelet_les_halles_L.xlsx, groupe : KSTest_2018-08-23_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-23_Chatelet_les_halles_P.xlsx, groupe : KSTest_2018-08-23_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-23_Chatelet_les_halles_T.xlsx, groupe : KSTest_2018-08-23_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-08-23_concorde.xlsx, groupe : KSTest_2018-08-23_concorde)
# Compute Clustering fichier : KSTest_2018-08-23_concorde_D.xlsx, groupe : KSTest_2018-08-23_concorde)
# Compute Clustering fichier : KSTest_2018-08-23_concorde_L.xlsx, groupe : KSTest_2018-08-23_concorde)
# Compute Clustering fichier : KSTest_2018-08-23_concorde_P.xlsx, groupe : KSTest_2018-08-23_concorde)
# Compute Clustering fichier : KSTest_2018-08-23_concorde_T.xlsx, groupe : KSTest_2018-08-23_concorde)
# Compute Clustering fichier : KSTest_2018-08-23_Gare_St_lazare.xlsx, groupe : KSTest_2018-08-23_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-23_Gare_St_lazare_D.xlsx, groupe : KSTest_2018-08-23_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-23_Gare_St_lazare_L.xlsx, groupe : KSTest_2018-08-23_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-23_Gare_St_lazare_P.xlsx, groupe : KSTest_2018-08-23_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-23_Gare_St_lazare_T.xlsx, groupe : KSTest_2018-08-23_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-08-23_residentiel.xlsx, groupe : KSTest_2018-08-23_residentiel)
# Compute Clustering fichier : KSTest_2018-08-23_residentiel_D.xlsx, groupe : KSTest_2018-08-23_residentiel)
# Compute Clustering fichier : KSTest_2018-08-23_residentiel_L.xlsx, groupe : KSTest_2018-08-23_residentiel)
# Compute Clustering fichier : KSTest_2018-08-23_residentiel_P.xlsx, groupe : KSTest_2018-08-23_residentiel)
# Compute Clustering fichier : KSTest_2018-08-23_residentiel_T.xlsx, groupe : KSTest_2018-08-23_residentiel)
# Compute Clustering fichier : KSTest_2018-08-23_rive_droite_seine.xlsx, groupe : KSTest_2018-08-23_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-23_rive_droite_seine_D.xlsx, groupe : KSTest_2018-08-23_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-23_rive_droite_seine_L.xlsx, groupe : KSTest_2018-08-23_rive_droite_)
# Compute Clustering fichier : KSTest_2018-08-23_rive_droite_seine_P.xlsx, groupe : KSTest_2018-08-23_rive_droite_)
# ...
# Compute Clustering fichier : KSTest_2018-09-02_concorde_P.xlsx, groupe : KSTest_2018-09-02_concorde)
# Compute Clustering fichier : KSTest_2018-09-02_concorde_T.xlsx, groupe : KSTest_2018-09-02_concorde)
# Compute Clustering fichier : KSTest_2018-09-02_Gare_St_lazare.xlsx, groupe : KSTest_2018-09-02_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-09-02_Gare_St_lazare_D.xlsx, groupe : KSTest_2018-09-02_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-09-02_Gare_St_lazare_L.xlsx, groupe : KSTest_2018-09-02_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-09-02_Gare_St_lazare_P.xlsx, groupe : KSTest_2018-09-02_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-09-02_Gare_St_lazare_T.xlsx, groupe : KSTest_2018-09-02_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-09-02_residentiel.xlsx, groupe : KSTest_2018-09-02_residentiel)
# Compute Clustering fichier : KSTest_2018-09-02_residentiel_D.xlsx, groupe : KSTest_2018-09-02_residentiel)
# Compute Clustering fichier : KSTest_2018-09-02_residentiel_L.xlsx, groupe : KSTest_2018-09-02_residentiel)
# Compute Clustering fichier : KSTest_2018-09-02_residentiel_P.xlsx, groupe : KSTest_2018-09-02_residentiel)
# Compute Clustering fichier : KSTest_2018-09-02_residentiel_T.xlsx, groupe : KSTest_2018-09-02_residentiel)
# Compute Clustering fichier : KSTest_2018-09-02_rive_droite_seine.xlsx, groupe : KSTest_2018-09-02_rive_droite_)
# Compute Clustering fichier : KSTest_2018-09-02_rive_droite_seine_D.xlsx, groupe : KSTest_2018-09-02_rive_droite_)
# Compute Clustering fichier : KSTest_2018-09-02_rive_droite_seine_L.xlsx, groupe : KSTest_2018-09-02_rive_droite_)
# Compute Clustering fichier : KSTest_2018-09-02_rive_droite_seine_P.xlsx, groupe : KSTest_2018-09-02_rive_droite_)
# Compute Clustering fichier : KSTest_2018-09-02_rive_droite_seine_T.xlsx, groupe : KSTest_2018-09-02_rive_droite_)
# Compute Clustering fichier : KSTest_2018-09-03_all.xlsx, groupe : KSTest_2018-09-03_all)
# Compute Clustering fichier : KSTest_2018-09-03_Chatelet_les_halles.xlsx, groupe : KSTest_2018-09-03_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-09-03_Chatelet_les_halles_D.xlsx, groupe : KSTest_2018-09-03_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-09-03_Chatelet_les_halles_L.xlsx, groupe : KSTest_2018-09-03_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-09-03_Chatelet_les_halles_P.xlsx, groupe : KSTest_2018-09-03_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-09-03_Chatelet_les_halles_T.xlsx, groupe : KSTest_2018-09-03_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-09-03_concorde.xlsx, groupe : KSTest_2018-09-03_concorde)
# Compute Clustering fichier : KSTest_2018-09-03_concorde_D.xlsx, groupe : KSTest_2018-09-03_concorde)
# Compute Clustering fichier : KSTest_2018-09-03_concorde_L.xlsx, groupe : KSTest_2018-09-03_concorde)
# Compute Clustering fichier : KSTest_2018-09-03_concorde_P.xlsx, groupe : KSTest_2018-09-03_concorde)
# Compute Clustering fichier : KSTest_2018-09-03_concorde_T.xlsx, groupe : KSTest_2018-09-03_concorde)
# Compute Clustering fichier : KSTest_2018-09-03_Gare_St_lazare.xlsx, groupe : KSTest_2018-09-03_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-09-03_Gare_St_lazare_D.xlsx, groupe : KSTest_2018-09-03_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-09-03_Gare_St_lazare_L.xlsx, groupe : KSTest_2018-09-03_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-09-03_Gare_St_lazare_P.xlsx, groupe : KSTest_2018-09-03_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-09-03_Gare_St_lazare_T.xlsx, groupe : KSTest_2018-09-03_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-09-03_residentiel.xlsx, groupe : KSTest_2018-09-03_residentiel)
# Compute Clustering fichier : KSTest_2018-09-03_residentiel_D.xlsx, groupe : KSTest_2018-09-03_residentiel)
# Compute Clustering fichier : KSTest_2018-09-03_residentiel_L.xlsx, groupe : KSTest_2018-09-03_residentiel)
# Compute Clustering fichier : KSTest_2018-09-03_residentiel_P.xlsx, groupe : KSTest_2018-09-03_residentiel)
# Compute Clustering fichier : KSTest_2018-09-03_residentiel_T.xlsx, groupe : KSTest_2018-09-03_residentiel)
# Compute Clustering fichier : KSTest_2018-09-03_rive_droite_seine.xlsx, groupe : KSTest_2018-09-03_rive_droite_)
# Compute Clustering fichier : KSTest_2018-09-03_rive_droite_seine_D.xlsx, groupe : KSTest_2018-09-03_rive_droite_)
# Compute Clustering fichier : KSTest_2018-09-03_rive_droite_seine_L.xlsx, groupe : KSTest_2018-09-03_rive_droite_)
# Compute Clustering fichier : KSTest_2018-09-03_rive_droite_seine_P.xlsx, groupe : KSTest_2018-09-03_rive_droite_)
# Compute Clustering fichier : KSTest_2018-09-03_rive_droite_seine_T.xlsx, groupe : KSTest_2018-09-03_rive_droite_)
# Compute Clustering fichier : KSTest_2018-09-04_all.xlsx, groupe : KSTest_2018-09-04_all)
# Compute Clustering fichier : KSTest_2018-09-04_Chatelet_les_halles.xlsx, groupe : KSTest_2018-09-04_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-09-04_Chatelet_les_halles_D.xlsx, groupe : KSTest_2018-09-04_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-09-04_Chatelet_les_halles_L.xlsx, groupe : KSTest_2018-09-04_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-09-04_Chatelet_les_halles_P.xlsx, groupe : KSTest_2018-09-04_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-09-04_Chatelet_les_halles_T.xlsx, groupe : KSTest_2018-09-04_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-09-04_concorde.xlsx, groupe : KSTest_2018-09-04_concorde)
# Compute Clustering fichier : KSTest_2018-09-04_concorde_D.xlsx, groupe : KSTest_2018-09-04_concorde)
# Compute Clustering fichier : KSTest_2018-09-04_concorde_L.xlsx, groupe : KSTest_2018-09-04_concorde)
# Compute Clustering fichier : KSTest_2018-09-04_concorde_P.xlsx, groupe : KSTest_2018-09-04_concorde)
# Compute Clustering fichier : KSTest_2018-09-04_concorde_T.xlsx, groupe : KSTest_2018-09-04_concorde)
# Compute Clustering fichier : KSTest_2018-09-04_Gare_St_lazare.xlsx, groupe : KSTest_2018-09-04_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-09-04_Gare_St_lazare_D.xlsx, groupe : KSTest_2018-09-04_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-09-04_Gare_St_lazare_L.xlsx, groupe : KSTest_2018-09-04_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-09-04_Gare_St_lazare_P.xlsx, groupe : KSTest_2018-09-04_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-09-04_Gare_St_lazare_T.xlsx, groupe : KSTest_2018-09-04_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-09-04_residentiel.xlsx, groupe : KSTest_2018-09-04_residentiel)
# Compute Clustering fichier : KSTest_2018-09-04_residentiel_D.xlsx, groupe : KSTest_2018-09-04_residentiel)
# Compute Clustering fichier : KSTest_2018-09-04_residentiel_L.xlsx, groupe : KSTest_2018-09-04_residentiel)
# Compute Clustering fichier : KSTest_2018-09-04_residentiel_P.xlsx, groupe : KSTest_2018-09-04_residentiel)
# Compute Clustering fichier : KSTest_2018-09-04_residentiel_T.xlsx, groupe : KSTest_2018-09-04_residentiel)
# Compute Clustering fichier : KSTest_2018-09-04_rive_droite_seine.xlsx, groupe : KSTest_2018-09-04_rive_droite_)
# Compute Clustering fichier : KSTest_2018-09-04_rive_droite_seine_D.xlsx, groupe : KSTest_2018-09-04_rive_droite_)
# Compute Clustering fichier : KSTest_2018-09-04_rive_droite_seine_L.xlsx, groupe : KSTest_2018-09-04_rive_droite_)
# Compute Clustering fichier : KSTest_2018-09-04_rive_droite_seine_P.xlsx, groupe : KSTest_2018-09-04_rive_droite_)
# Compute Clustering fichier : KSTest_2018-09-04_rive_droite_seine_T.xlsx, groupe : KSTest_2018-09-04_rive_droite_)
# Compute Clustering fichier : KSTest_2018-09-05_all.xlsx, groupe : KSTest_2018-09-05_all)
# Compute Clustering fichier : KSTest_2018-09-05_Chatelet_les_halles.xlsx, groupe : KSTest_2018-09-05_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-09-05_Chatelet_les_halles_D.xlsx, groupe : KSTest_2018-09-05_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-09-05_Chatelet_les_halles_L.xlsx, groupe : KSTest_2018-09-05_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-09-05_Chatelet_les_halles_P.xlsx, groupe : KSTest_2018-09-05_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-09-05_Chatelet_les_halles_T.xlsx, groupe : KSTest_2018-09-05_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-09-05_concorde.xlsx, groupe : KSTest_2018-09-05_concorde)
# Compute Clustering fichier : KSTest_2018-09-05_concorde_D.xlsx, groupe : KSTest_2018-09-05_concorde)
# Compute Clustering fichier : KSTest_2018-09-05_concorde_L.xlsx, groupe : KSTest_2018-09-05_concorde)
# Compute Clustering fichier : KSTest_2018-09-05_concorde_P.xlsx, groupe : KSTest_2018-09-05_concorde)
# Compute Clustering fichier : KSTest_2018-09-05_concorde_T.xlsx, groupe : KSTest_2018-09-05_concorde)
# Compute Clustering fichier : KSTest_2018-09-05_Gare_St_lazare.xlsx, groupe : KSTest_2018-09-05_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-09-05_Gare_St_lazare_D.xlsx, groupe : KSTest_2018-09-05_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-09-05_Gare_St_lazare_L.xlsx, groupe : KSTest_2018-09-05_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-09-05_Gare_St_lazare_P.xlsx, groupe : KSTest_2018-09-05_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-09-05_Gare_St_lazare_T.xlsx, groupe : KSTest_2018-09-05_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-09-05_residentiel.xlsx, groupe : KSTest_2018-09-05_residentiel)
# Compute Clustering fichier : KSTest_2018-09-05_residentiel_D.xlsx, groupe : KSTest_2018-09-05_residentiel)
# Compute Clustering fichier : KSTest_2018-09-05_residentiel_L.xlsx, groupe : KSTest_2018-09-05_residentiel)
# Compute Clustering fichier : KSTest_2018-09-05_residentiel_P.xlsx, groupe : KSTest_2018-09-05_residentiel)
# Compute Clustering fichier : KSTest_2018-09-05_residentiel_T.xlsx, groupe : KSTest_2018-09-05_residentiel)
# Compute Clustering fichier : KSTest_2018-09-05_rive_droite_seine.xlsx, groupe : KSTest_2018-09-05_rive_droite_)
# Compute Clustering fichier : KSTest_2018-09-05_rive_droite_seine_D.xlsx, groupe : KSTest_2018-09-05_rive_droite_)
# Compute Clustering fichier : KSTest_2018-09-05_rive_droite_seine_L.xlsx, groupe : KSTest_2018-09-05_rive_droite_)
# Compute Clustering fichier : KSTest_2018-09-05_rive_droite_seine_P.xlsx, groupe : KSTest_2018-09-05_rive_droite_)
# Compute Clustering fichier : KSTest_2018-09-05_rive_droite_seine_T.xlsx, groupe : KSTest_2018-09-05_rive_droite_)
# Compute Clustering fichier : KSTest_2018-09-06_all.xlsx, groupe : KSTest_2018-09-06_all)
# Compute Clustering fichier : KSTest_2018-09-06_Chatelet_les_halles.xlsx, groupe : KSTest_2018-09-06_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-09-06_Chatelet_les_halles_D.xlsx, groupe : KSTest_2018-09-06_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-09-06_Chatelet_les_halles_L.xlsx, groupe : KSTest_2018-09-06_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-09-06_Chatelet_les_halles_P.xlsx, groupe : KSTest_2018-09-06_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-09-06_Chatelet_les_halles_T.xlsx, groupe : KSTest_2018-09-06_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-09-06_concorde.xlsx, groupe : KSTest_2018-09-06_concorde)
# Compute Clustering fichier : KSTest_2018-09-06_concorde_D.xlsx, groupe : KSTest_2018-09-06_concorde)
# Compute Clustering fichier : KSTest_2018-09-06_concorde_L.xlsx, groupe : KSTest_2018-09-06_concorde)
# Compute Clustering fichier : KSTest_2018-09-06_concorde_P.xlsx, groupe : KSTest_2018-09-06_concorde)
# Compute Clustering fichier : KSTest_2018-09-06_concorde_T.xlsx, groupe : KSTest_2018-09-06_concorde)
# Compute Clustering fichier : KSTest_2018-09-06_Gare_St_lazare.xlsx, groupe : KSTest_2018-09-06_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-09-06_Gare_St_lazare_D.xlsx, groupe : KSTest_2018-09-06_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-09-06_Gare_St_lazare_L.xlsx, groupe : KSTest_2018-09-06_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-09-06_Gare_St_lazare_P.xlsx, groupe : KSTest_2018-09-06_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-09-06_Gare_St_lazare_T.xlsx, groupe : KSTest_2018-09-06_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-09-06_residentiel.xlsx, groupe : KSTest_2018-09-06_residentiel)
# Compute Clustering fichier : KSTest_2018-09-06_residentiel_D.xlsx, groupe : KSTest_2018-09-06_residentiel)
# Compute Clustering fichier : KSTest_2018-09-06_residentiel_L.xlsx, groupe : KSTest_2018-09-06_residentiel)
# Compute Clustering fichier : KSTest_2018-09-06_residentiel_P.xlsx, groupe : KSTest_2018-09-06_residentiel)
# Compute Clustering fichier : KSTest_2018-09-06_residentiel_T.xlsx, groupe : KSTest_2018-09-06_residentiel)
# Compute Clustering fichier : KSTest_2018-09-06_rive_droite_seine.xlsx, groupe : KSTest_2018-09-06_rive_droite_)
# Compute Clustering fichier : KSTest_2018-09-06_rive_droite_seine_D.xlsx, groupe : KSTest_2018-09-06_rive_droite_)
# Compute Clustering fichier : KSTest_2018-09-06_rive_droite_seine_L.xlsx, groupe : KSTest_2018-09-06_rive_droite_)
# Compute Clustering fichier : KSTest_2018-09-06_rive_droite_seine_P.xlsx, groupe : KSTest_2018-09-06_rive_droite_)
# Compute Clustering fichier : KSTest_2018-09-06_rive_droite_seine_T.xlsx, groupe : KSTest_2018-09-06_rive_droite_)
# Compute Clustering fichier : KSTest_2018-09-07_all.xlsx, groupe : KSTest_2018-09-07_all)
# Compute Clustering fichier : KSTest_2018-09-07_Chatelet_les_halles.xlsx, groupe : KSTest_2018-09-07_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-09-07_Chatelet_les_halles_D.xlsx, groupe : KSTest_2018-09-07_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-09-07_Chatelet_les_halles_L.xlsx, groupe : KSTest_2018-09-07_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-09-07_Chatelet_les_halles_P.xlsx, groupe : KSTest_2018-09-07_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-09-07_Chatelet_les_halles_T.xlsx, groupe : KSTest_2018-09-07_Chatelet_les)
# Compute Clustering fichier : KSTest_2018-09-07_concorde.xlsx, groupe : KSTest_2018-09-07_concorde)
# Compute Clustering fichier : KSTest_2018-09-07_concorde_D.xlsx, groupe : KSTest_2018-09-07_concorde)
# Compute Clustering fichier : KSTest_2018-09-07_concorde_L.xlsx, groupe : KSTest_2018-09-07_concorde)
# Compute Clustering fichier : KSTest_2018-09-07_concorde_P.xlsx, groupe : KSTest_2018-09-07_concorde)
# Compute Clustering fichier : KSTest_2018-09-07_concorde_T.xlsx, groupe : KSTest_2018-09-07_concorde)
# Compute Clustering fichier : KSTest_2018-09-07_Gare_St_lazare.xlsx, groupe : KSTest_2018-09-07_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-09-07_Gare_St_lazare_D.xlsx, groupe : KSTest_2018-09-07_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-09-07_Gare_St_lazare_L.xlsx, groupe : KSTest_2018-09-07_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-09-07_Gare_St_lazare_P.xlsx, groupe : KSTest_2018-09-07_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-09-07_Gare_St_lazare_T.xlsx, groupe : KSTest_2018-09-07_Gare_St_laza)
# Compute Clustering fichier : KSTest_2018-09-07_residentiel.xlsx, groupe : KSTest_2018-09-07_residentiel)
# Compute Clustering fichier : KSTest_2018-09-07_residentiel_D.xlsx, groupe : KSTest_2018-09-07_residentiel)
# Compute Clustering fichier : KSTest_2018-09-07_residentiel_L.xlsx, groupe : KSTest_2018-09-07_residentiel)
# Compute Clustering fichier : KSTest_2018-09-07_residentiel_P.xlsx, groupe : KSTest_2018-09-07_residentiel)
# Compute Clustering fichier : KSTest_2018-09-07_residentiel_T.xlsx, groupe : KSTest_2018-09-07_residentiel)
# Compute Clustering fichier : KSTest_2018-09-07_rive_droite_seine.xlsx, groupe : KSTest_2018-09-07_rive_droite_)
# Compute Clustering fichier : KSTest_2018-09-07_rive_droite_seine_D.xlsx, groupe : KSTest_2018-09-07_rive_droite_)
# Compute Clustering fichier : KSTest_2018-09-07_rive_droite_seine_L.xlsx, groupe : KSTest_2018-09-07_rive_droite_)
# Compute Clustering fichier : KSTest_2018-09-07_rive_droite_seine_P.xlsx, groupe : KSTest_2018-09-07_rive_droite_)
# Compute Clustering fichier : KSTest_2018-09-07_rive_droite_seine_T.xlsx, groupe : KSTest_2018-09-07_rive_droite_)

# %%
#Normal Statistics
kpiList = ['CQImoyen','TraficDataDL','TraficDataUL',
           'VoIPqualitymeasinsuffstat','CROZON_NombredeConnexionsPS','nbUEVoIPqualityOK',
           'Nbrtentatives_QCi5__TEAVoix']
computing_type = "single"
liste_data = os.listdir(local_path + "/data/")
time_struct={}
last_group = ''
dayList = np.array([datetime(2018,8,7)+timedelta(days=i) for i in range(0,32)])
for current_data in liste_data:
    current_group = current_data.replace("_D.xlsx", "")
    current_group = current_group.replace("_L.xlsx", "")
    current_group = current_group.replace("_T.xlsx", "")
    current_group = current_group.replace("_P.xlsx", "")
    current_group = current_group.replace(".xlsx", "")
    if current_group != last_group:
        time_struct={}
    last_group = current_group    
    ZoneDataFrame=pd.read_excel(local_path + "/data/" + current_data)
    if computing_type == 'single':
        time_struct[current_data]={}
        print("Compute Statistics_Single fichier : {}, groupe : {})".format(current_data, current_group))
        for cell in ZoneDataFrame['CellName'].unique():
            results = Statistics(ZoneCellsKpi,cell,kpiList,dayList)
            fic_result= local_path + "/Statistics/results1_MeanMaxMin_PerDay/" +'MeanMaxMin_PerDay_'+str(cell)+current_data
            writer_results = pd.ExcelWriter(fic_result)
            results.to_excel(writer_results)
            writer_results.save()

    elif computing_type == 'parallel':
        time_struct[current_data]={}
        print("Compute KS_Single fichier : {}, groupe : {})".format(current_data, current_group))
        results = KSTestAllCellsParallel(ZoneCellsKpi,kpiList,dayList)
        for day in dayList:
            fic_result= local_path + "/KSTest/results5_ClusteringTimeSeries/" +'clustering_ts_'+str(cell)+groupe
            fic_time= local_path + "/KSTest/compute_time/" + "time_KS_" +str(day.date())+'_' +current_group + ".xlsx"
            writer_results = pd.ExcelWriter(fic_result)
            writer_time = pd.ExcelWriter(fic_time)
            for kpi in kpiList:
                KpiPvalueMatrix = results[day][kpi]
                KpiPvalueMatrix.to_excel(writer_results,sheet_name=kpi)
        writer_time.save()
        writer_results.save()
# Out:
# Compute Statistics_Single fichier : all.xlsx, groupe : all)
# Compute Statistics_Single fichier : Chatelet_les_halles.xlsx, groupe : Chatelet_les_halles)
# Compute Statistics_Single fichier : Chatelet_les_halles_D.xlsx, groupe : Chatelet_les_halles)
# Compute Statistics_Single fichier : Chatelet_les_halles_L.xlsx, groupe : Chatelet_les_halles)
# Compute Statistics_Single fichier : Chatelet_les_halles_P.xlsx, groupe : Chatelet_les_halles)
# Compute Statistics_Single fichier : Chatelet_les_halles_T.xlsx, groupe : Chatelet_les_halles)
# Compute Statistics_Single fichier : concorde.xlsx, groupe : concorde)
# Compute Statistics_Single fichier : concorde_D.xlsx, groupe : concorde)
# Compute Statistics_Single fichier : concorde_L.xlsx, groupe : concorde)
# Compute Statistics_Single fichier : concorde_P.xlsx, groupe : concorde)
# Compute Statistics_Single fichier : concorde_T.xlsx, groupe : concorde)
# Compute Statistics_Single fichier : Gare_St_lazare.xlsx, groupe : Gare_St_lazare)
# Compute Statistics_Single fichier : Gare_St_lazare_D.xlsx, groupe : Gare_St_lazare)
# Compute Statistics_Single fichier : Gare_St_lazare_L.xlsx, groupe : Gare_St_lazare)
# Compute Statistics_Single fichier : Gare_St_lazare_P.xlsx, groupe : Gare_St_lazare)
# Compute Statistics_Single fichier : Gare_St_lazare_T.xlsx, groupe : Gare_St_lazare)
# Compute Statistics_Single fichier : residentiel.xlsx, groupe : residentiel)
# Compute Statistics_Single fichier : residentiel_D.xlsx, groupe : residentiel)
# Compute Statistics_Single fichier : residentiel_L.xlsx, groupe : residentiel)
# Compute Statistics_Single fichier : residentiel_P.xlsx, groupe : residentiel)
# Compute Statistics_Single fichier : residentiel_T.xlsx, groupe : residentiel)
# Compute Statistics_Single fichier : rive_droite_seine.xlsx, groupe : rive_droite_seine)
# Compute Statistics_Single fichier : rive_droite_seine_D.xlsx, groupe : rive_droite_seine)
# Compute Statistics_Single fichier : rive_droite_seine_L.xlsx, groupe : rive_droite_seine)
# Compute Statistics_Single fichier : rive_droite_seine_P.xlsx, groupe : rive_droite_seine)
# Compute Statistics_Single fichier : rive_droite_seine_T.xlsx, groupe : rive_droite_seine)

# %%
def linearMap(x,r,MAX,MIN):
    return((1-r)*(x-MAX)/(MAX-MIN)+1)

# %%
kpiList = ['CQImoyen','TraficDataDL','TraficDataUL',
           'VoIPqualitymeasinsuffstat','CROZON_NombredeConnexionsPS','nbUEVoIPqualityOK',
           'Nbrtentatives_QCi5__TEAVoix']
#Creating Clustering Time Series Data
computing_type = "single"
liste_data = os.listdir(local_path + "/KSTest/results4_ClustersDays/")
time_struct={}
last_group = ''
auxList = []
num = 0
groupe = 'all.xlsx'
for current_data in liste_data:
    if current_data.endswith(groupe): 
        ZoneCellsKpi = pd.read_excel(local_path + "/KSTest/results4_ClustersDays/" + current_data)
        for kpi in ZoneCellsKpi.columns:
            #ZoneCellsKpi[kpi] =len(ZoneCellsKpi)/ZoneCellsKpi.groupby(kpi)[kpi].transform('count')
            ZoneCellsKpi[kpi] = ZoneCellsKpi.groupby(kpi)[kpi].transform('count')/len(ZoneCellsKpi)
            ZoneCellsKpi[kpi] = (ZoneCellsKpi[kpi]-ZoneCellsKpi[kpi].min())/(ZoneCellsKpi[kpi].max()-ZoneCellsKpi[kpi].min())
            #ZoneCellsKpi[kpi] = ZoneCellsKpi[kpi]*ZoneCellsKpi[kpi].apply(lambda x: linearMap(x,0.1,ZoneCellsKpi[kpi].max(),ZoneCellsKpi[kpi].min()))
        ZoneCellsKpi.index.name = 'Cell_Name'
        ZoneCellsKpi['Tec'] = [cell[0] for cell in ZoneCellsKpi.index]
        ZoneCellsKpi.columns = [str(col)+' '+str(num) for col in ZoneCellsKpi.columns]
        num = num+1
        auxList.append(ZoneCellsKpi)
alldaysClusters = functools.reduce(lambda left,right: pd.merge(left,right,on='Cell_Name'), auxList)
kpiList.append('Tec')
for cell in alldaysClusters.index:
    cellAllKpi = pd.DataFrame()
    for kpi in kpiList:
        cellkpiSeries = alldaysClusters.loc[cell][alldaysClusters.columns[alldaysClusters.columns.str.startswith(kpi)]]
        cellAllKpi[kpi] = np.array(cellkpiSeries)
    fic_result= local_path + "/KSTest/results5_ClusteringTimeSeries/" +'clustering_ts_'+str(cell)+groupe
    writer_results = pd.ExcelWriter(fic_result)
    cellAllKpi.to_excel(writer_results)
    writer_results.save()

# %%
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	n_vars = 1 if type(data) is list else data.shape[1]
	df = pd.DataFrame(data)
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
		names += [(name+'(t-%d)' % (i)) for name in data.columns]
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df.shift(-i))
		if i == 0:
			names += [name+'(t)' for name in data.columns]
		else:
			names += [(name+'(t+%d)' % (i)) for name in data.columns]
	# put it all together
	agg = pd.concat(cols, axis=1)
	agg.columns = names
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg

# %%
groupe= 'all'
#Creating Clustering Supervised Data
computing_type = "single"
liste_data = os.listdir(local_path + "/KSTest/results5_ClusteringTimeSeries/")
allCellSupervisedData = pd.DataFrame()
predictive_time_units = 1
to_predict_time_units = 7
for current_data in liste_data:
    if groupe in current_data:
        timeSeries = pd.read_excel(local_path + "/KSTest/results5_ClusteringTimeSeries/" + current_data)
        cellSupervisedData = series_to_supervised(timeSeries, n_in=predictive_time_units, n_out=to_predict_time_units, dropnan=True)
        allCellSupervisedData = allCellSupervisedData.append(cellSupervisedData, ignore_index=True)
    
fic_result= local_path + "/KSTest/results6_ClusteringSupervisedData/" +'supervised_' +groupe+str(predictive_time_units)+'_'+str(to_predict_time_units)+'.xlsx'
writer_results = pd.ExcelWriter(fic_result)
allCellSupervisedData.to_excel(writer_results)
writer_results.save()

# %%
cellKpi= pd.read_excel(r'C:\Users\euripab\Desktop\ML Extraction\KSTEST\results5_ClusteringTimeSeries\clustering_ts_all_D10562A.xlsx')
cellKpi.plot(y =cellAllKpi.columns, kind='line',figsize = (15,10))

# %%
ZoneCellsKpi=pd.read_excel(r'C:\Users\euripab\Desktop\ML Extraction\data\all.xlsx')

# %%
dayList = np.array([datetime(2018,8,7)+timedelta(days=i) for i in range(0,32)])

# %%
results = KSTestAllCells(ZoneCellsKpi,kpiList,dayList)

# %%
for day in dayList:
    fic_result= local_path + "/KSTest/results3_PvaluesDays/" + "KSTest_"+str(day.date())+'_all.xlsx' 
    writer_results = pd.ExcelWriter(fic_result)
    for kpi in kpiList:
        KpiPvalueMatrix = results[day][kpi]
        KpiPvalueMatrix.to_excel(writer_results,sheet_name=kpi)
    writer_results.save()

# %%
groupe= '_all_'
#Creating Clustering Supervised Data
computing_type = "single"
liste_data = os.listdir(local_path + "/KSTest/results5_ClusteringTimeSeries/")
allCellSupervisedData = pd.DataFrame()
predictive_time_units = 14
to_predict_time_units = 1
for current_data in liste_data:
    if groupe in current_data:
        timeSeries1 = pd.read_excel(local_path + "/KSTest/results5_ClusteringTimeSeries/" + current_data)
        cellSupervisedData = series_to_supervised(timeSeries1, n_in=predictive_time_units, n_out=to_predict_time_units, dropnan=True)
        allCellSupervisedData = allCellSupervisedData.append(cellSupervisedData, ignore_index=True)
    
fic_result= local_path + "/KSTest/results6_ClusteringSupervisedData/" +'supervised_' +groupe+str(predictive_time_units)+'_'+str(to_predict_time_units)+'.xlsx'
writer_results = pd.ExcelWriter(fic_result)
allCellSupervisedData.to_excel(writer_results)
writer_results.save()

# %%
groupe= '_all_'
#Creating MeanMaxMin Supervised Data
computing_type = "single"
liste_data = os.listdir(local_path + "/Statistics/results1_MeanMaxMin_PerDay/")
allCellSupervisedData = pd.DataFrame()
predictive_time_units = 14
to_predict_time_units = 1
for current_data in liste_data:
    if groupe in current_data:
        timeSeries1 = pd.read_excel(local_path + "/Statistics/results1_MeanMaxMin_PerDay/" + current_data)
        cellSupervisedData = series_to_supervised(timeSeries1, n_in=predictive_time_units, n_out=to_predict_time_units, dropnan=True)
        allCellSupervisedData = allCellSupervisedData.append(cellSupervisedData, ignore_index=True)
    
fic_result= local_path + "/Statistics/results2_MeanMaxMin_SupervisedData/" +'supervised' +groupe+str(predictive_time_units)+'_'+str(to_predict_time_units)+'.xlsx'
writer_results = pd.ExcelWriter(fic_result)
allCellSupervisedData.to_excel(writer_results)
writer_results.save()
